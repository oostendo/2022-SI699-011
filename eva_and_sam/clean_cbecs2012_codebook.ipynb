# %%
import pandas as pd
import re

# %%
def map_code_values(category_code_list, print_errors=False):
    equal_split = re.compile(r'\s?=\s?')
    cont_num_range = re.compile(r'\d+\s?-\s?\d+')
    code_map = {}
    error_map = {}
    i = 0 # col index
    for code_list in category_code_list:
        # check codes to follow "num = category pattern"
        if 'no code' in code_list:
            code_list = ['no code = continuous numerical value']
        if bool(cont_num_range.search(code_list[0])) == True:
            # if numerical range is first ie "1 - 10"
            code_list[0] = code_list[0] + ' = continuous numerical range'
        elif bool(cont_num_range.search(code_list[-1])) == True:
            # if numerical range is last ie "1946 - 2012"
            code_list[-1] = code_list[-1] + ' = continuous numerical range'
        elif 'continued' in code_list[-1]:
            # if (continued in next cell) is last, delete from list
            del code_list[-1]

        # convert codes to dict
        try:
            code_map[i] = dict([re.split(equal_split.pattern, code.replace("'", "").strip()) for code in code_list])
        except ValueError as e:
            error_map[i] = (code_list, e)
        
        # increment col index
        i += 1
    if print_errors == True:
        for k,v in error_map.items():
            print(f'codelist: {k} | error: {v}\n-----------')
    return code_map

# %%
codebook_col_map = {
    'CATEOGORIES': 'category', 
    'File order': 'file_order', 
    'Variable\r\nname': 'col_name', 
    'Variable type': 'col_type',
    'Len-\r\ngth': 'length', 
    'Format': 'format', 
    'Label': 'col_description', 
    'Values/Format codes': 'codes', 
    'Unnamed: 8': 'empty_col' # (continued in next cell) code prompt?
}
df_codebook = pd.read_csv('031022-codebook.csv').rename(columns=codebook_col_map).drop(['empty_col'], axis=1)
df_codebook.head(5)
# Out:
#   category  file_order col_name col_type  length    format  \
# 0        0         1.0    PUBID     Char     5.0       NaN
# 1        0         2.0   REGION     Char     1.0  $REGION.
# 2        0         3.0   CENDIV     Char     1.0  $CENDIV.
# 3        0         4.0      PBA     Char     2.0     $PBA.
# 4        1         5.0  FREESTN     Char     1.0     $YES.
#
#                col_description  \
# 0          Building identifier
# 1                Census region
# 2              Census division
# 3  Principal building activity
# 4        Freestanding building
#
#                                                codes
# 0                                      00001 - 06720
# 1  '1' = 'Northeast'\r\n'2' = 'Midwest'\r\n'3' = ...
# 2  '1' = 'New England'\r\n'2' = 'Middle Atlantic'...
# 3  '01' = 'Vacant'\r\n'02' = 'Office'\r\n'04' = '...
# 4                        1' = 'Yes'\r\nMissing='No'

# %%
categories = df_codebook.category.unique()
print(f'categories: {categories}')
category_map = {}
category_dfs = {}
for cat_name in categories:
    if cat_name != 'get rid of':
        category_map[cat_name] = df_codebook[df_codebook['category'] == cat_name].col_name.values
        category_dfs[cat_name] = df_codebook[df_codebook['category'] == cat_name]
print(f"category = 1 columns: {category_map['0']}")
category_dfs['0']
# Out:
# categories: ['0' '1' '2' '3' '4' '5' '6' '7' 'get rid of' '10']
# category = 1 columns: ['PUBID' 'REGION' 'CENDIV' 'PBA']
#   category  file_order col_name col_type  length    format  \
# 0        0         1.0    PUBID     Char     5.0       NaN
# 1        0         2.0   REGION     Char     1.0  $REGION.
# 2        0         3.0   CENDIV     Char     1.0  $CENDIV.
# 3        0         4.0      PBA     Char     2.0     $PBA.
#
#                col_description  \
# 0          Building identifier
# 1                Census region
# 2              Census division
# 3  Principal building activity
#
#                                                codes
# 0                                      00001 - 06720
# 1  '1' = 'Northeast'\r\n'2' = 'Midwest'\r\n'3' = ...
# 2  '1' = 'New England'\r\n'2' = 'Middle Atlantic'...
# 3  '01' = 'Vacant'\r\n'02' = 'Office'\r\n'04' = '...

# %%
# NOTE: some codes span two rows
# need to find a way to concatenate this, then update map_codes function '(continued in next cell)' condition
category_dfs['1'].iloc[44:48]
# Out:
#    category  file_order col_name col_type  length     format  \
# 48        1        49.0  ACT3PCT      Num     8.0        NaN
# 49        1        50.0  PBAPLUS     Char     2.0  $PBAPLUS.
# 50        1         NaN      NaN      NaN     NaN        NaN
# 51        1        51.0    DRYCL     Char     1.0   $DRYCLN.
#
#                                col_description  \
# 48             Percent used for third activity
# 49             More specific building activity
# 50  More specific building activity, continued
# 51                         Dry cleaning onsite
#
#                                                 codes
# 48                1 - 100\r\nMissing = Not applicable
# 49  '01' = 'Vacant'\r\n'02' = 'Administrative/prof...
# 50  '28' = 'Elementary/middle school'\r\n'29' = 'H...
# 51  '1' = 'In this building'\r\n'2' = 'Off-site'\r...

# %%
# only category 10 has missing codes
category_dfs['10'].loc[:,'codes'] = category_dfs['10'].codes.fillna('no code')
category_dfs['10'].head()
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#      category  file_order col_name col_type  length   format  \
# 1049       10      1049.0    HDD65      Num     8.0      NaN
# 1050       10      1050.0    CDD65      Num     8.0      NaN
# 1051       10      1051.0   MFUSED     Char     1.0  $YESNO.
# 1052       10      1052.0    MFBTU      Num     8.0      NaN
# 1053       10      1053.0    MFEXP      Num     8.0      NaN
#
#                                 col_description  \
# 1049              Heating degree days (base 65)
# 1050              Cooling degree days (base 65)
# 1051                        Any major fuel used
# 1052  Annual major fuel consumption (thous Btu)
# 1053         Annual major fuel expenditures ($)
#
#                                                   codes
# 1049                                            no code
# 1050                                            no code
# 1051  '1' = 'Yes'\r\n'2' = 'No'\r\nMissing = Not app...
# 1052                                            no code
# 1053                                            no code

# %%
all_cats_code_maps = {}
for cat_num, df in category_dfs.items(): 
    print(f'category: {cat_num}')
    if cat_num != 'get rid of':
        i = 0
        category_code_df = category_dfs[cat_num].drop(['category', 'file_order', 'col_type', 'length', 'format',], axis=1)
        category_code_df['code_split'] = category_code_df.codes.str.split('\n')
        category_code_list = category_code_df.code_split.values
        category_cols = category_code_df.columns
        category_code_map = map_code_values(category_code_list, print_errors=True)
        for col_name in category_code_df.col_name.values:
            category_code_map[col_name] = category_code_map.pop(i)
            i += 1
        all_cats_code_maps[cat_num] = category_code_map
# Out:
# category: 0
# category: 1
# category: 2
# category: 3
# category: 4
# category: 5
# category: 6
# category: 7
# category: 10

# %%
for cat_num, code_map in all_cats_code_maps.items():
    print(cat_num)
    print(code_map)
    print('---------------------------------------------------------------------------------------------------------')
# Out:
# 0
# {'PUBID': {'00001 - 06720': 'continuous numerical range'}, 'REGION': {'1': 'Northeast', '2': 'Midwest', '3': 'South', '4': 'West'}, 'CENDIV': {'1': 'New England', '2': 'Middle Atlantic', '3': 'East North Central', '4': 'West North Central', '5': 'South Atlantic', '6': 'East South Central', '7': 'West South Central', '8': 'Mountain', '9': 'Pacific'}, 'PBA': {'01': 'Vacant', '02': 'Office', '04': 'Laboratory', '05': 'Nonrefrigerated warehouse', '06': 'Food sales', '07': 'Public order and safety', '08': 'Outpatient health care', '11': 'Refrigerated warehouse', '12': 'Religious worship', '13': 'Public assembly', '14': 'Education', '15': 'Food service', '16': 'Inpatient health care', '17': 'Nursing', '18': 'Lodging', '23': 'Strip shopping mall', '24': 'Enclosed mall', '25': 'Retail other than mall', '26': 'Service', '91': 'Other'}}
# ---------------------------------------------------------------------------------------------------------
# 1
# {'FREESTN': {'1': 'Yes', 'Missing': 'No'}, 'SQFT': {'1,001 - 1,500,000': 'continuous numerical range'}, 'SQFTC': {'01': '1,000 square feet or less', '02': '1,001 to 5,000 square feet', '03': '5,001 to 10,000 square feet', '04': '10,001 to 25,000 square feet', '05': '25,001 to 50,000 square feet', '06': '50,001 to 100,000 square feet', '07': '100,001 to 200,000 square feet', '08': '200,001 to 500,000 square feet', '09': '500,001 to 1 million square feet', '10': 'Over 1 million square feet'}, 'WLCNS': {'1': 'Brick, stone, or stucco', '2': 'Pre-cast concrete panels', '3': 'Concrete block or poured concrete (above grade)', '4': 'Aluminum, asbestos, plastic, or wood materials (siding, shingles, tiles, or shakes)', '5': 'Sheet metal panels', '6': 'Window or vision glass (glass that can be seen through)', '7': 'Decorative or construction glass', '8': 'No one major type', '9': 'Other'}, 'RFCNS': {'1': 'Built-up (tar, felts, or fiberglass and a ballast, such as stone)', '2': 'Slate or tile shingles', '3': 'Wood shingles, shakes, or other wooden materials', '4': 'Asphalt, fiberglass, or other shingles', '5': 'Metal surfacing', '6': 'Plastic, rubber, or synthetic sheeting (single or multiple ply)', '7': 'Concrete', '8': 'No one major type', '9': 'Other'}, 'RFCOOL': {'1': 'Yes', '2': 'No'}, 'RFTILT': {'1': 'Flat', '2': 'Shallow pitch', '3': 'Steeper pitch'}, 'BLDSHP': {'01': 'Square', '02': 'Wide rectangle', '03': 'Narrow rectangle', '04': 'Rectangle or square with an interior courtyard', '05': '"H" shaped', '06': '"U" shaped', '07': '"E" shaped', '08': '"T" shaped', '09': '"L" shaped', '10': '"+" or cross shaped', '11': 'Other shape', 'Missing': 'Not applicable'}, 'GLSSPC': {'1': '1 percent or less', '2': '2 to 10 percent', '3': '11 to 25 percent', '4': '26 to 50 percent', '5': '51 to 75 percent', '6': '76 to 100 percent', 'Missing': 'Not applicable'}, 'EQGLSS': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SUNGLS': {'1': 'More glass area', '2': 'Less glass area', '3': 'About the same amount', 'Missing': 'Not applicable'}, 'NFLOOR': {'1 - 14\r': 'continuous numerical range', '994': '15 to 25', '995': 'More than 25'}, 'BASEMNT': {'0 - 7\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'FLCEILHT': {'6 - 50\r': 'continuous numerical range', '995': 'More than 50'}, 'ATTIC': {'1': 'Yes', '2': 'No'}, 'ELEVTR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NELVTR': {'1 - 50\r': 'continuous numerical range', '995': 'More than 50'}, 'ESCLTR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NESLTR': {'1 - 20\r': 'continuous numerical range', '995': 'More than 20'}, 'YRCON': {'995': 'Before 1946', '1946 - 2012': 'continuous numerical range'}, 'YRCONC': {'01': 'Before 1920', '02': '1920 to 1945', '03': '1946 to 1959', '04': '1960 to 1969', '05': '1970 to 1979', '06': '1980 to 1989', '07': '1990 to 1999', '08': '2000 to 2003', '09': '2004 to 2007', '10': '2008 to 2012'}, 'MONCON': {'01': 'January', '02': 'February', '03': 'March', '04': 'April', '05': 'May', '06': 'June', '07': 'July', '08': 'August', '09': 'September', '10': 'October', '11': 'November', '12': 'December', '97': 'Undetermined', 'Missing': 'Not applicable'}, 'RENOV': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENADD': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENRDC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENCOS': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENINT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENRFF': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENWLL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENWIN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENHVC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENLGT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENPLB': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENELC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENINS': {'1': 'Yes', '2': 'No', 'M ...
# ---------------------------------------------------------------------------------------------------------
# 2
# {'GOVOWN': {'1': 'Yes', '2': 'No'}, 'GOVTYP': {'1': 'Federal', '2': 'State', '3': 'Local', '7': 'Withheld to protect confidentiality', 'Missing': 'Not applicable'}, 'OWNTYPE': {'01': 'Real estate investment trust (REIT)', '02': 'Other public or private corporation, partnership, LLC, or LLP', '03': 'Individual owner(s)', '04': 'Religious organization', '05': 'Non-profit organization (other than religious or government)', '06': 'Private academic institution', '07': 'Other non-government', '08': 'Federal government', '09': 'State government', '10': 'Local government', '97': 'Withheld to protect confidentiality'}, 'NOCC': {'0 - 200\r': 'continuous numerical range', '995': 'More than 200'}, 'NOCCAT': {'01': 'Zero', '02': 'One', '03': '2 to 5', '04': '6 to 10', '05': '11 to 20', '06': '21 to 50', '07': '51 to 100', '08': 'More than 100'}, 'OWNOCC': {'1': 'Owner occupied', '2': 'Leased to tenant(s)', '3': 'Combination occupied and leased', 'Missing': 'Not applicable'}, 'OWNOPR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OWNPPR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NWNPPR': {'1': 'Property management company or leasing agent', '2': 'Business owner or tenant', '3': 'Facilities personnel employed directly by the building owner', '4': 'Facilities or energy management consultant', '5': 'Volunteer member of the organization', '6': 'Manager with general supervisory duties', '7': 'Other', 'Missing': 'Not applicable'}, 'NWNOPR': {'1': 'Property management company or leasing agent', '2': 'Business owner or tenant', '3': 'Facilities personnel employed directly by the building owner', '4': 'Facilities or energy management consultant', '5': 'Volunteer member of the organization', '6': 'Manager with general supervisory duties', '7': 'Other', 'Missing': 'Not applicable'}, 'WHOPPR': {'1': 'Building owner', '2': 'Party responsible for building operations', '3': 'Both (either they have equal input, or are the same person)', '4': 'Other', 'Missing': 'Not applicable'}}
# ---------------------------------------------------------------------------------------------------------
# 3
# {'MONUSE': {'0 - 12': 'continuous numerical range'}, 'OCCUPYP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LODOCCP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'OPEN24': {'1': 'Yes', '2': 'No'}, 'OPNMF': {'1': 'All five days', '2': 'Some of these days', '3': 'Not open at all Monday through Friday'}, 'OPNWE': {'1': 'Yes', '2': 'No'}, 'WKHRS': {'0 - 168': 'continuous numerical range'}, 'WKHRSC': {'1': 'No hours', '2': '1 to 39', '3': '40 to 48', '4': '49 to 60', '5': '61 to 84', '6': '85 to 167', '7': '168'}, 'NWKER': {'0 - 6,500': 'continuous numerical range'}, 'NWKERC': {'01': 'None', '02': '1 to 4', '03': '5 to 9', '04': '10 to 19', '05': '20 to 49', '06': '50 to 99', '07': '100 to 249', '08': '250 to 499', '09': '500 to 999', '10': '1,000 to 2,499', '11': '2,500 to 4,999', '12': '5,000 or More'}}
# ---------------------------------------------------------------------------------------------------------
# 4
# {'HT1': {'1': 'Yes', '2': 'No'}, 'HT2': {'1': 'Yes', '2': 'No'}, 'COOL': {'1': 'Yes', '2': 'No'}, 'WATR': {'1': 'Yes', '2': 'No'}, 'COOK': {'1': 'Yes', '2': 'No'}, 'MANU': {'1': 'Yes', '2': 'No'}, 'CAPGEN': {'1': 'Yes', '2': 'No'}, 'GENR': {'1': 'Yes', '2': 'No'}, 'ANYEGY': {'1': 'Yes, some energy was used in 2012', '2': 'No, no energy was used'}, 'ELUSED': {'1': 'Yes', '2': 'No'}, 'NGUSED': {'1': 'Yes', '2': 'No'}, 'FKUSED': {'1': 'Yes', '2': 'No'}, 'FKTYPE': {'1': 'Fuel oil', '2': 'Diesel', '3': 'Kerosene', '4': 'Fuel oil and diesel', '5': 'Fuel oil and kerosene', '6': 'Diesel and kerosene', '7': 'Fuel oil, diesel, and kerosene', '9': 'Dont know'}, 'PRUSED': {'1': 'Yes', '2': 'No'}, 'STUSED': {'1': 'Yes', '2': 'No'}, 'HWUSED': {'1': 'Yes', '2': 'No'}, 'CWUSED': {'1': 'Yes', '2': 'No'}, 'WOUSED': {'1': 'Yes', '2': 'No'}, 'COUSED': {'1': 'Yes', '2': 'No'}, 'SOUSED': {'1': 'Yes', '2': 'No'}, 'OTUSED': {'1': 'Yes', '2': 'No'}, 'ELHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NGHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FKHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PRHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'STHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HWHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WOHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'COHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SOHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'ELHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NGHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FKHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PRHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'STHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HWHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WOHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'COHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SOHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HEATP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HTLS50': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FURNAC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PKGHT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BOILER': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'STHW': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HTPMPH': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SLFCON': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTHTEQ': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FURNP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'PKGHP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'BOILP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'STHWP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HTPHP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'SLFCNP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'OTHTP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'MAINHT': {'1': 'Furnaces that heat air directly, without using steam or hot water', '2': 'Packaged central unit (roof mounted)', '3': 'Boilers inside (or adjacent to) the building that produce steam or hot water', '4': 'District steam or hot water piped in from outside the building', '5': 'Heat pumps (other than components of a packaged unit)', '6': 'Individual space heaters (other than heat pumps)', '7': 'Other heating equipment', 'Missing': 'Not applicable'}, 'NWMNHT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PKGHTTYP': {'1': 'Factory-assembled unitary packaged unit', '2': 'Custom built-up packaged unit ...
# ---------------------------------------------------------------------------------------------------------
# 5
# {'AMIMETER': {'1': 'Yes', '2': 'No', '7': 'Undetermined', '8': 'Refused', '9': 'Dont know', 'Missing': 'Not applicable'}, 'ENRGYPLN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}}
# ---------------------------------------------------------------------------------------------------------
# 6
# {'SNACK': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FASTFD': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'CAF': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FDPREP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'KITCHN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BREAKRM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTFDRM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HWTRM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LAUNDR': {'1': 'In this building', '2': 'In another building on-site', '3': 'By an off-site laundry service', 'Missing': 'Not applicable'}, 'CONFSP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'CONFSPP': {'1 - 50\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'MEDEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'XRAYN': {'0 - 20\r': 'continuous numerical range', '995': 'More than 20', 'Missing': 'Not applicable'}, 'CTSCAN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'MRI': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LINACC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OUTSURG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LABEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'MCHEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'POOL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HTPOOL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'POOLSRC': {'1': 'Electricity', '2': 'Natural gas', '3': 'Fuel oil/Diesel/Kerosene', '4': 'Bottled gas/LPG/Propane', '5': 'Solar', '6': 'Some other energy source', 'Missing': 'Not applicable'}, 'STRLZR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGRES': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGCOMP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGWI': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGOP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGCL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGVEN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGICE': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGSTO': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGRSN': {'1 - 1,000\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGCOMPN': {'1 - 1,000\r': 'continuous numerical range', '99995': 'More than 1,000', 'Missing': 'Not applicable'}, 'RFGWIN': {'1 - 350\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGOPN': {'1 - 300\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGCLN': {'1 - 500\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGVNN': {'1 - 300\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGICN': {'1 - 500\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGSTP': {'1 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'WHRECOV': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WHHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WHWT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WHOT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PCTERM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PCTERMN': {'0 - 4,195\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'PCTRMC': {'00': 'Zero', '01': '1 to 4', '02': '5 to 9', '03': '10 to 19', '04': '20 to 49', '05': '50 to 99', '06': '100 to 249', '07': '250 to 499', '08': '500 to 999', '09': '1,000 to 2,499', '10': '2,500 or more', 'Missing': 'Not applicable'}, 'MLTMON': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'MLTMNC': {'1': 'All', '2': 'Most', '3': 'Some', '4': 'A few', 'Missing': 'Not applicable'}, 'FLATC': {'1': 'All', '2': 'Most', '3': 'Some', '4': 'A few', '5': 'None', 'Missing': 'Not applicable'}, 'LAPTPN': {'0 - 1,420\r': 'continuous numerical range', 'Missing': 'Not ap ...
# ---------------------------------------------------------------------------------------------------------
# 7
# {'LTOHRP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LOHRPC': {'1': '1 to 25 percent', '2': '26 to 50 percent', '3': '51 to 75 percent', '4': '76 to 100 percent', '5': 'Not lit at all when it is normally open', 'Missing': 'Not applicable'}, 'LTNR24': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LTNHRP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LNHRPC': {'1': '1 to 25 percent', '2': '26 to 50 percent', '3': '51 to 75 percent', '4': '76 to 100 percent', '5': 'Not lit at all during off hours', 'Missing': 'Not applicable'}, 'RDLTNF': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FLUOR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'CFLR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BULB': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HALO': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HID': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LED': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTLT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FLUORP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'CFLRP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'BULBP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HALOP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HIDP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LEDP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'OTLTP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}, 'EMCSLT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SCHED': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OCSN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DIM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DAYHARV': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'TRIM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PLGCTRL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DRLGHT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LTEXPC': {'1': 'Less than 10 percent', '2': '10 to 25 percent', '3': '25 to 50 percent', '4': 'More than 50 percent', 'Missing': 'Not applicable'}, 'PKLT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WINTYP': {'1': 'Single layer glass', '2': 'Multi-layer glass', '3': 'Combination of both', '4': 'No windows'}, 'TINT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'REFL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'AWN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SKYLT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DAYLTP': {'0 - 100\r': 'continuous numerical range', 'Missing': 'Not applicable'}}
# ---------------------------------------------------------------------------------------------------------
# 10
# {'HDD65': {'no code': 'continuous numerical value'}, 'CDD65': {'no code': 'continuous numerical value'}, 'MFUSED': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'MFBTU': {'no code': 'continuous numerical value'}, 'MFEXP': {'no code': 'continuous numerical value'}, 'ELCNS': {'no code': 'continuous numerical value'}, 'ELBTU': {'no code': 'continuous numerical value'}, 'ELEXP': {'no code': 'continuous numerical value'}, 'NGCNS': {'no code': 'continuous numerical value'}, 'NGBTU': {'no code': 'continuous numerical value'}, 'NGEXP': {'no code': 'continuous numerical value'}, 'FKCNS': {'no code': 'continuous numerical value'}, 'FKBTU': {'no code': 'continuous numerical value'}, 'FKEXP': {'no code': 'continuous numerical value'}, 'DHUSED': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHHT1': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHCOOL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHCOOK': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHWATR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHMANU': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHOTH': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DHCNS': {'no code': 'continuous numerical value'}, 'DHBTU': {'no code': 'continuous numerical value'}, 'DHEXP': {'no code': 'continuous numerical value'}, 'ZMFBTU': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZMFEXP': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZELCNS': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZELEXP': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZNGCNS': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZNGEXP': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZFKCNS': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZFKEXP': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZDHCNS': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'ZDHEXP': {'0': 'Reported', '1': 'Estimated for strip center', '2': 'Imputed', '3': 'Estimated using price', '9': 'Inapplicable'}, 'MFHTBTU': {'no code': 'continuous numerical value'}, 'MFCLBTU': {'no code': 'continuous numerical value'}, 'MFVNBTU': {'no code': 'continuous numerical value'}, 'MFWTBTU': {'no code': 'continuous numerical value'}, 'MFLTBTU': {'no code': 'continuous numerical value'}, 'MFCKBTU': {'no code': 'continuous numerical value'}, 'MFRFBTU': {'no code': 'continuous numerical value'}, 'MFOFBTU': {'no code': 'continuous numerical value'}, 'MFPCBTU': {'no code': 'continuous numerical value'}, 'MFOTBTU': {'no code': 'continuous numerical value'}, 'ELHTBTU': {'no code': 'continuous numerical value'}, 'ELCLBTU': {'no code': 'continuous numerical value'}, 'ELVNBTU': {'no code': 'continuous numerical value'}, 'ELWTBTU': {'no code': 'continuous numerical value'}, 'ELLTBTU': {'no code': 'continuous numerical value'}, 'ELCKBTU': {'no code': 'continuous numerical value'}, 'ELRFBTU': {'no code': 'continuous numerical value'}, 'ELOFBTU': {'no code': 'continuous numerical value'}, 'ELPCBTU': {'no code': 'continuous numerical value'}, 'ELOTBTU': {'no code': 'continuous numerical value'}, 'NGHTBTU': {'no code': 'continuous numerical value'}, 'NGCLBTU': {'no code': 'continuous numerical value'}, 'NGWTBTU': {'no code': 'continuous numerical value'}, 'NGCKBTU': {'no code': 'continuous numeric ...
# ---------------------------------------------------------------------------------------------------------

# %%
new_codes_df = pd.DataFrame(all_cats_code_maps)
print(new_codes_df.columns)
new_codes_df['0'].dropna()
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7', '10'], dtype='object')
# PUBID       {'00001 - 06720': 'continuous numerical range'}
# REGION    {'1': 'Northeast', '2': 'Midwest', '3': 'South...
# CENDIV    {'1': 'New England', '2': 'Middle Atlantic', '...
# PBA       {'01': 'Vacant', '02': 'Office', '04': 'Labora...
# Name: 0, dtype: object

# %%
to_add_dfs = []
for category_num in new_codes_df.columns:
    to_add = new_codes_df[category_num].dropna().reset_index().rename(columns={'index':'col_name', category_num:'codes_dict'})
    to_add_dfs.append(to_add)
to_merge = pd.concat(to_add_dfs)

# %%
new_codebook = df_codebook.merge(to_merge, on='col_name')
new_codebook#.drop_duplicates(subset='col_name')
# Out:
#     category  file_order col_name col_type  length     format  \
# 0          0         1.0    PUBID     Char     5.0        NaN
# 1          0         2.0   REGION     Char     1.0   $REGION.
# 2          0         3.0   CENDIV     Char     1.0   $CENDIV.
# 3          0         4.0      PBA     Char     2.0      $PBA.
# 4          1         5.0  FREESTN     Char     1.0      $YES.
# ..       ...         ...      ...      ...     ...        ...
# 512       10      1115.0  DHCLBTU      Num     8.0        NaN
# 513       10      1116.0  DHWTBTU      Num     8.0        NaN
# 514       10      1117.0  DHCKBTU      Num     8.0        NaN
# 515       10      1118.0  DHOTBTU      Num     8.0        NaN
# 516       10      1119.0  PUBCLIM     Char     1.0  $PUBCLIM.
#
#                                  col_description  \
# 0                            Building identifier
# 1                                  Census region
# 2                                Census division
# 3                    Principal building activity
# 4                          Freestanding building
# ..                                           ...
# 512        District heat cooling use (thous Btu)
# 513  District heat water heating use (thous Btu)
# 514        District heat cooking use (thous Btu)
# 515  District heat miscellaneous use (thous Btu)
# 516              Building America climate region
#
#                                                  codes  \
# 0                                        00001 - 06720
# 1    '1' = 'Northeast'\n'2' = 'Midwest'\n'3' = 'Sou...
# 2    '1' = 'New England'\n'2' = 'Middle Atlantic'\n...
# 3    '01' = 'Vacant'\n'02' = 'Office'\n'04' = 'Labo...
# 4                            1' = 'Yes'\nMissing='No'
# ..                                                 ...
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516  1' = 'Very cold/Cold'\n'2 '= 'Mixed-humid'\n'3...
#
#                                             codes_dict
# 0      {'00001 - 06720': 'continuous numerical range'}
# 1    {'1': 'Northeast', '2': 'Midwest', '3': 'South...
# 2    {'1': 'New England', '2': 'Middle Atlantic', '...
# 3    {'01': 'Vacant', '02': 'Office', '04': 'Labora...
# 4                        {'1': 'Yes', 'Missing': 'No'}
# ..                                                 ...
# 512          {'no code': 'continuous numerical value'}
# 513          {'no code': 'continuous numerical value'}
# 514          {'no code': 'continuous numerical value'}
# 515          {'no code': 'continuous numerical value'}
# 516  {'1': 'Very cold/Cold', '2': 'Mixed-humid', '3...
#
# [517 rows x 9 columns]

# %%
new_codebook.to_csv('2012cbecs_codebook_wDicts.csv', index=False)
