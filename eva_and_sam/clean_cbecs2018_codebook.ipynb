# %%
import pandas as pd
import re

# %%
def map_code_values(category_code_list, print_errors=False):
    equal_split = re.compile(r'\s?=\s?')
    cont_num_range = re.compile(r'^\d+\,?\d+?\s?-\s?\d+\,?\d+|^\d+\s?-\s?\d+\,?\d+|^\d+?\s?-\s?\d+')
    code_map = {}
    error_map = {}
    i = 0 # col index
    for code_list in category_code_list:
        # check codes to follow "num = category pattern"
        if 'no code' in code_list:
            code_list = ['no code = continuous numerical value']
        if bool(cont_num_range.search(code_list[0])) == True:
            # if numerical range is first ie "1 - 10"
            code_list[0] = code_list[0] + ' = continuous numerical range'
        elif bool(cont_num_range.search(code_list[-1])) == True:
            # if numerical range is last ie "1946 - 2012"
            code_list[-1] = code_list[-1] + ' = continuous numerical range'
        elif 'continued' in code_list[-1]:
            # if (continued in next cell) is last, delete from list
            del code_list[-1]

        # convert codes to dict
        try:
            code_map[i] = dict([re.split(equal_split.pattern, code.replace("'", "").strip()) for code in code_list])
        except ValueError as e:
            error_map[i] = (code_list, e)
        
        # increment col index
        i += 1
    if print_errors == True:
        for k,v in error_map.items():
            print(f'codelist: {k} | error: {v}\n-----------')
    return code_map

# %%
codebook_col_map = {
    'CATEOGORIES': 'category', 
    'File order': 'file_order', 
    'Variable\nname': 'col_name', 
    'Variable type': 'col_type',
    'Length': 'length', 
    'Label': 'col_description', 
    'Values/Format codes': 'codes', 
    'Unnamed: 8': 'empty_col' # (continued in next cell) code prompt?
}
#df_codebook = pd.read_csv('2018microdata_codebook.csv').rename(columns=codebook_col_map).drop(['empty_col'], axis=1)
df_codebook = pd.read_csv('2018microdata_codebook.csv').rename(columns=codebook_col_map)
df_codebook.head(5)
# Out:
#   category  file_order col_name col_type  length  \
# 0        0           1    PUBID     Char       5
# 1        0           2   REGION     Char       1
# 2        0           3   CENDIV     Char       1
# 3        0           4      PBA      Num       8
# 4        1           5     SQFT      Num       8
#
#                        col_description  \
# 0  Public use file building identifier
# 1                        Census Region
# 2                      Census division
# 3          Principal building activity
# 4                       Square footage
#
#                                                codes
# 0                                      00001 - 06436
# 1            1=Northeast\n2=Midwest\n3=South\n4=West
# 2  1=New England\n2=Middle Atlantic  \n3=East Nor...
# 3  1=Vacant\n2=Office\n4=Laboratory\n5=Nonrefrige...
# 4                                  1,001 - 2,100,000

# %%
categories = df_codebook.category.unique()
print(f'categories: {categories}')
category_map = {}
category_dfs = {}
for cat_name in categories:
    if cat_name != 'get rid of':
        category_map[cat_name] = df_codebook[df_codebook['category'] == cat_name].col_name.values
        category_dfs[cat_name] = df_codebook[df_codebook['category'] == cat_name]
print(f"category = 1 columns: {category_map['0']}")
category_dfs['0']
# Out:
# categories: ['0' '1' 'get rid of' '2' '3' '4' '5' '6' '7']
# category = 1 columns: ['PUBID' 'REGION' 'CENDIV' 'PBA']
#   category  file_order col_name col_type  length  \
# 0        0           1    PUBID     Char       5
# 1        0           2   REGION     Char       1
# 2        0           3   CENDIV     Char       1
# 3        0           4      PBA      Num       8
#
#                        col_description  \
# 0  Public use file building identifier
# 1                        Census Region
# 2                      Census division
# 3          Principal building activity
#
#                                                codes
# 0                                      00001 - 06436
# 1            1=Northeast\n2=Midwest\n3=South\n4=West
# 2  1=New England\n2=Middle Atlantic  \n3=East Nor...
# 3  1=Vacant\n2=Office\n4=Laboratory\n5=Nonrefrige...

# %%
# only category 10 has missing codes
# category_dfs['10'].loc[:,'codes'] = category_dfs['10'].codes.fillna('no code')
# category_dfs['10'].head()

# %%
all_cats_code_maps = {}
for cat_num, df in category_dfs.items(): 
    print(f'category: {cat_num}')
    if cat_num != 'get rid of':
        i = 0
        category_code_df = category_dfs[cat_num].drop(['category', 'file_order', 'col_type', 'length',], axis=1)
        category_code_df['code_split'] = category_code_df.codes.str.split('\n')
        category_code_list = category_code_df.code_split.values
        category_cols = category_code_df.columns
        category_code_map = map_code_values(category_code_list, print_errors=True)
        for col_name in category_code_df.col_name.values:
            category_code_map[col_name] = category_code_map.pop(i)
            i += 1
        all_cats_code_maps[cat_num] = category_code_map
# Out:
# category: 0
# category: 1
# category: 2
# category: 3
# category: 4
# category: 5
# category: 6
# category: 7

# %%
for cat_num, code_map in all_cats_code_maps.items():
    print(cat_num)
    print(code_map)
    print('---------------------------------------------------------------------------------------------------------')
# Out:
# 0
# {'PUBID': {'00001 - 06436': 'continuous numerical range'}, 'REGION': {'1': 'Northeast', '2': 'Midwest', '3': 'South', '4': 'West'}, 'CENDIV': {'1': 'New England', '2': 'Middle Atlantic', '3': 'East North Central', '4': 'West North Central', '5': 'South Atlantic', '6': 'East South Central', '7': 'West South Central', '8': 'Mountain', '9': 'Pacific'}, 'PBA': {'1': 'Vacant', '2': 'Office', '4': 'Laboratory', '5': 'Nonrefrigerated warehouse', '6': 'Food sales', '7': 'Public order and safety', '8': 'Outpatient health care', '11': 'Refrigerated warehouse', '12': 'Religious worship', '13': 'Public assembly', '14': 'Education', '15': 'Food service', '16': 'Inpatient health care', '17': 'Nursing', '18': 'Lodging', '23': 'Strip shopping center', '24': 'Enclosed mall', '25': 'Retail other than mall', '26': 'Service', '91': 'Other'}}
# ---------------------------------------------------------------------------------------------------------
# 1
# {'SQFT': {'1,001 - 2,100,000': 'continuous numerical range'}, 'SQFTC': {'2': '1,001 to 5,000 square feet', '3': '5,001 to 10,000 square feet', '4': '10,001 to 25,000 square feet', '5': '25,001 to 50,000 square feet', '6': '50,001 to 100,000 square feet', '7': '100,001 to 200,000 square feet', '8': '200,001 to 500,000 square feet', '9': '500,001 to 1 million square feet', '10': 'Over 1 million square feet'}, 'WLCNS': {'1': 'Brick, stone, or stucco', '2': 'Pre-cast concrete panels', '3': 'Concrete block or poured concrete (above grade)', '4': 'Aluminum, asbestos, plastic, or wood materials (siding, shingles, tiles)', '5': 'Sheet metal panels', '6': 'Window or vision glass (glass that can be seen through)', '7': 'Decorative or construction glass (glass that cannot be seen through)', '8': 'Other'}, 'RFCNS': {'1': 'Built-up (tar, felts, or fiberglass and a ballast, such as stone)', '2': 'Slate or tile shingles', '3': 'Wood shingles, shakes, or other wooden materials', '4': 'Asphalt, fiberglass, or other shingles', '5': 'Metal surfacing', '6': 'Plastic, rubber, or synthetic sheeting (single or multiple ply)', '7': 'Concrete', '8': 'Other'}, 'RFCOOL': {'1': 'Yes', '2': 'No'}, 'RFTILT': {'1': 'Flat', '2': 'Shallow pitch', '3': 'Steeper pitch'}, 'BLDSHP': {'1': 'Square', '2': 'Wide rectangle', '3': 'Narrow rectangle', '4': 'Rectangle or square with an interior courtyard', '5': '"H" shaped', '6': '"U" shaped', '7': '"E" shaped', '8': '"T" shaped', '9': '"L" shaped', '10': '"+" or cross shaped', '11': 'Other shape'}, 'GLSSPC': {'1': '1% or less', '2': '2 to 10%', '3': '11 to 25%', '4': '26 to 50%', '5': '51 to 75%', '6': '76 to 100%'}, 'NFLOOR': {'1 - 9': 'continuous numerical range', '994': '10 - 14', '995': '15 or more'}, 'BASEMNT': {'0 - 4': 'continuous numerical range', '995': '5 or more', 'Missing': 'Not applicable'}, 'FLCEILHT': {'7 - 50': 'continuous numerical range', '995': 'More than 50'}, 'ATTIC': {'1': 'Yes', '2': 'No'}, 'ELEVTR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NELVTR': {'1 - 30': 'continuous numerical range', '995': 'More than 30', 'Missing': 'Not applicable'}, 'ESCLTR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NESLTR': {'1 - 10': 'continuous numerical range', '995': 'More than 10', 'Missing': 'Not applicable'}, 'YRCONC': {'2': 'Before 1946', '3': '1946 to 1959', '4': '1960 to 1969', '5': '1970 to 1979', '6': '1980 to 1989', '7': '1990 to 1999', '8': '2000 to 2012', '9': '2013 to 2018'}, 'RENOV': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENCOS': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENADD': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENRDC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENINT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENRFF': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENWIN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENHVC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENLGT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENPLB': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENELC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENINS': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENSAF': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENSTR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RENOTH': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'ONEACT': {'1': 'Yes', '2': 'No'}, 'DRYCL': {'1': 'In this building', '2': 'Off-site', 'Missing': 'Not applicable'}, 'VACANT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PBAPLUS': {'1': 'Vacant', '2': 'Administrative/professional office', '3': 'Bank/other financial', '4': 'Government office', '5': 'Medical office (non-diagnostic)', '6': 'Mixed-use office', '7': 'Other office', '8': 'Laboratory', '9': 'Distribution/shipping center', '10': 'Non-refrigerated warehouse', '11': 'Public rental storage units', '12': 'Convenience store (w/ or w/out gas station) ...
# ---------------------------------------------------------------------------------------------------------
# 2
# {'GOVOWN': {'1': 'Yes', '2': 'No'}, 'GOVTYP': {'1': 'Federal', '2': 'State', '3': 'Local', '7': 'Withheld to protect confidentiality', 'Missing': 'Not applicable'}, 'OWNTYPE': {'1': 'Real estate investment trust (REIT)', '2': 'Other public or private corporation, partnership, LLC, or LLP', '3': 'Individual owner(s)', '4': 'Religious organization', '5': 'Non-profit organization (other than religious or government)', '6': 'Private academic institution', '7': 'Other', '8': 'Federal government', '9': 'State government', '10': 'Local government', '97': 'Withheld to protect confidentiality'}, 'NOCC': {'0 - 200': 'continuous numerical range', '996': 'Withheld to protect confidentiality'}, 'NOCCAT': {'1': 'Zero', '2': 'One', '3': '2 to 5', '4': '6 to 10', '5': '11 to 20', '6': '21 to 50', '7': '51 to 100', '8': 'More than 100', '996': 'Withheld to protect confidentiality'}, 'OWNOCC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OWNOPR': {'1': 'Yes', '2': 'No'}, 'OWNPPR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'NWNPPR': {'1': 'Property management company or leasing agent', '2': 'Business owner or tenant', '3': 'Facilities personnel employed directly by the building owner', '4': 'Facilities or energy management consultant', '5': 'Volunteer member of the organization', '6': 'Manager with general supervisory duties', '7': 'Other', 'Missing': 'Not applicable'}, 'NWNOPR': {'1': 'Property management company or leasing agent', '2': 'Business owner or tenant', '3': 'Facilities personnel employed directly by the building owner', '4': 'Facilities or energy management consultant', '5': 'Volunteer member of the organization', '6': 'Manager with general supervisory duties', '7': 'Other', 'Missing': 'Not applicable'}, 'WHOPPR': {'1': 'Building owner', '2': 'Party responsible for operation of energy systems', '3': 'Both (either they have equal input, or are the same person)', '4': 'Other', 'Missing': 'Not applicable'}}
# ---------------------------------------------------------------------------------------------------------
# 3
# {'MONUSE': {'0 - 12': 'continuous numerical range'}, 'OCCUPYP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LODOCCP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'OPEN24': {'1': 'Yes', '2': 'No'}, 'OPNMF': {'1': 'All five days', '2': 'Some of these days', '3': 'Not open at all Monday through Friday'}, 'OPNWE': {'1': 'Yes', '2': 'No'}, 'WKHRS': {'0 - 168': 'continuous numerical range'}, 'WKHRSC': {'1': 'No hours', '2': '1 to 39', '3': '40 to 48', '4': '49 to 60', '5': '61 to 84', '6': '85 to 167', '7': '168'}, 'NWKER': {'0 - 6,500': 'continuous numerical range'}, 'NWKERC': {'1': 'None', '2': '1 to 4', '3': '5 to 9', '4': '10 to 19', '5': '20 to 49', '6': '50 to 99', '7': '100 to 249', '8': '250 to 499', '9': '500 to 999', '10': '1,000 to 2,499', '11': '2,500 to 4,999', '12': '5,000 or More'}}
# ---------------------------------------------------------------------------------------------------------
# 4
# {'HT1': {'1': 'Yes', '2': 'No'}, 'HT2': {'1': 'Yes', '2': 'No'}, 'COOL': {'1': 'Yes', '2': 'No'}, 'WATR': {'1': 'Yes', '2': 'No'}, 'COOK': {'1': 'Yes', '2': 'No'}, 'MANU': {'1': 'Yes', '2': 'No'}, 'EGYUSED': {'1': 'Yes', '2': 'No'}, 'ELUSED': {'1': 'Yes', '2': 'No'}, 'NGUSED': {'1': 'Yes', '2': 'No'}, 'FKUSED': {'1': 'Yes', '2': 'No'}, 'PRUSED': {'1': 'Yes', '2': 'No'}, 'STUSED': {'1': 'Yes', '2': 'No'}, 'HWUSED': {'1': 'Yes', '2': 'No'}, 'CWUSED': {'1': 'Yes', '2': 'No'}, 'WOUSED': {'1': 'Yes', '2': 'No'}, 'COUSED': {'1': 'Yes', '2': 'No'}, 'SOUSED': {'1': 'Yes', '2': 'No'}, 'OTUSED': {'1': 'Yes', '2': 'No'}, 'FKTYPE': {'1': 'Fuel oil', '2': 'Diesel', '3': 'Kerosene', '4': 'Fuel oil and diesel', '5': 'Fuel oil and kerosene', '6': 'Diesel and kerosene', '7': 'Fuel oil, diesel, and kerosene', 'Missing': 'Not applicable'}, 'SOPANEL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SOTHERM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HEATP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HTLS50': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'ELHT1': {'1': 'Yes', '2': 'No'}, 'NGHT1': {'1': 'Yes', '2': 'No'}, 'FKHT1': {'1': 'Yes', '2': 'No'}, 'PRHT1': {'1': 'Yes', '2': 'No'}, 'STHT1': {'1': 'Yes', '2': 'No'}, 'HWHT1': {'1': 'Yes', '2': 'No'}, 'WOHT1': {'1': 'Yes', '2': 'No'}, 'COHT1': {'1': 'Yes', '2': 'No'}, 'SOHT1': {'1': 'Yes', '2': 'No'}, 'OTHT1': {'1': 'Yes', '2': 'No'}, 'ELHT2': {'1': 'Yes', '2': 'No'}, 'NGHT2': {'1': 'Yes', '2': 'No'}, 'FKHT2': {'1': 'Yes', '2': 'No'}, 'PRHT2': {'1': 'Yes', '2': 'No'}, 'STHT2': {'1': 'Yes', '2': 'No'}, 'HWHT2': {'1': 'Yes', '2': 'No'}, 'WOHT2': {'1': 'Yes', '2': 'No'}, 'COHT2': {'1': 'Yes', '2': 'No'}, 'SOHT2': {'1': 'Yes', '2': 'No'}, 'OTHT2': {'1': 'Yes', '2': 'No'}, 'PKGHT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FURNAC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SLFCON': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BOILER': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HTPMPH': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'STHW': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'REHEAT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FIREPLC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTHTEQ': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PKGHT_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BOILER_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HTPMPH_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FURNAC_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SLFCON_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FIREPLC_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'REHEAT_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTHTEQ_EL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PKGHT_NG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BOILER_NG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HTPMPH_NG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FURNAC_NG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SLFCON_NG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FIREPLC_NG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTHTEQ_NG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BOILER_FK': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FURNAC_FK': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SLFCON_FK': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTHTEQ_FK': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PKGHT_PR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BOILER_PR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HTPMPH_PR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FURNAC_PR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SLFCON_PR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FIREPLC_PR': {'1': 'Yes', '2': ...
# ---------------------------------------------------------------------------------------------------------
# 5
# {'ENRGYPLN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}}
# ---------------------------------------------------------------------------------------------------------
# 6
# {'SNACK': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FASTFD': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'CAF': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FDPREP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'KITCHN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BREAKRM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTFDRM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SNACKSF': {'50 - 90,000': 'continuous numerical range', 'Missing': 'Not applicable'}, 'FASTFDSF': {'10 - 100,000': 'continuous numerical range', 'Missing': 'Not applicable'}, 'CAFSF': {'270 - 108,000': 'continuous numerical range', 'Missing': 'Not applicable'}, 'FDPREPSF': {'50 - 180,000': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HWTRM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LAUNDR': {'1': 'In this building', '2': 'In another building on-site', '3': 'By an off-site laundry service', 'Missing': 'Not applicable'}, 'CONFSP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'CONFSPP': {'1 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'MEDEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'XRAYN': {'0 - 20': 'continuous numerical range', '995': 'More than 20', 'Missing': 'Not applicable'}, 'CTSCAN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'MRI': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LINACC': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OUTSURG': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OUTHOSPPCT': {'1': '0-20%', '2': '21-40%', '3': '41% or more', 'Missing': 'Not applicable'}, 'LABEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'MCHEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'POOL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HTPOOL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'POOLSRC': {'1': 'Electricity', '2': 'Natural gas', '3': 'Fuel oil/Diesel/Kerosene', '4': 'Propane', '5': 'Solar', '6': 'Some other energy source', 'Missing': 'Not applicable'}, 'STRLZR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGEQP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGRES': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGCOMP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGWI': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGOP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGCL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGVEN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGICE': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGSTO': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'RFGRSN': {'1 - 1,000': 'continuous numerical range', '99995': 'More than 1,000', 'Missing': 'Not applicable'}, 'RFGCOMPN': {'1 - 1,000': 'continuous numerical range', '9995': 'More than 1,000', 'Missing': 'Not applicable'}, 'RFGWIN': {'1 - 22': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGOPN': {'1 - 54': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGCLN': {'1 - 107': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGVNN': {'1 - 50': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGICN': {'1 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'RFGSTP': {'1 - 97': 'continuous numerical range', 'Missing': 'Not appplicable'}, 'WHRECOV': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WHHT2': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WHWT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'WHOT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PCTERM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LAPTOP': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'TABLET': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SERVER': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PCTERMN': {'1 - 3,615': 'continuous numeric ...
# ---------------------------------------------------------------------------------------------------------
# 7
# {'LTZHRP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LZHRPC': {'1': '1 to 25 percent', '2': '26 to 50 percent', '3': '51 to 75 percent', '4': '76 to 100 percent', '5': 'Not lit at all', 'Missing': 'Not applicable'}, 'LTOHRP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LOHRPC': {'1': '1 to 25 percent', '2': '26 to 50 percent', '3': '51 to 75 percent', '4': '76 to 100 percent', '5': 'Not lit at all', 'Missing': 'Not applicable'}, 'LTNR24': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LTNHRP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LNHRPC': {'1': '1 to 25 percent', '2': '26 to 50 percent', '3': '51 to 75 percent', '4': '76 to 100 percent', '5': 'Not lit at all during off hours', 'Missing': 'Not applicable'}, 'LIT': {'1': 'Yes', '2': 'No'}, 'FLUOR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'CFLR': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'BULB': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HALO': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'HID': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LED': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OTLT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'FLUORP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'CFLRP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'BULBP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HALOP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'HIDP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'LEDP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'OTLTP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}, 'SCHED': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'OCSN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DIM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DAYHARV': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'TRIM': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PLGCTRL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DRLGHT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'LTEXPC': {'1': 'Less than 10 percent', '2': '10 to 25 percent', '3': '25 to 50 percent', '4': 'More than 50 percent', 'Missing': 'Not applicable'}, 'PKLT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'PKLTINOUT': {'1': 'Part of the building (indoor)', '2': 'Separate parking (lot or garage)', '3': 'Both types of parking areas', 'Missing': 'Not applicable'}, 'PKLTN': {'6 - 12000': 'continuous numerical range', '5': '1 to 5', 'Missing': 'Not applicable'}, 'WINTYP': {'1': 'Single-layer glass', '2': 'Multi-layer glass', '3': 'Combination of both', '4': 'No windows'}, 'TINT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'REFL': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'AWN': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'SKYLT': {'1': 'Yes', '2': 'No', 'Missing': 'Not applicable'}, 'DAYLTP': {'0 - 100': 'continuous numerical range', 'Missing': 'Not applicable'}}
# ---------------------------------------------------------------------------------------------------------

# %%
new_codes_df = pd.DataFrame(all_cats_code_maps)
print(new_codes_df.columns)
new_codes_df['0'].dropna()
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')
# PUBID       {'00001 - 06436': 'continuous numerical range'}
# REGION    {'1': 'Northeast', '2': 'Midwest', '3': 'South...
# CENDIV    {'1': 'New England', '2': 'Middle Atlantic', '...
# PBA       {'1': 'Vacant', '2': 'Office', '4': 'Laborator...
# Name: 0, dtype: object

# %%
to_add_dfs = []
for category_num in new_codes_df.columns:
    to_add = new_codes_df[category_num].dropna().reset_index().rename(columns={'index':'col_name', category_num:'codes_dict'})
    to_add_dfs.append(to_add)
to_merge = pd.concat(to_add_dfs)

# %%
new_codebook = df_codebook.merge(to_merge, on='col_name')
new_codebook#.drop_duplicates(subset='col_name')
# Out:
#     category  file_order col_name col_type  length  \
# 0          0           1    PUBID     Char       5
# 1          0           2   REGION     Char       1
# 2          0           3   CENDIV     Char       1
# 3          0           4      PBA      Num       8
# 4          1           5     SQFT      Num       8
# ..       ...         ...      ...      ...     ...
# 556        7         558     TINT      Num       8
# 557        7         559     REFL      Num       8
# 558        7         560      AWN      Num       8
# 559        7         561    SKYLT      Num       8
# 560        7         562   DAYLTP      Num       8
#
#                                     col_description  \
# 0               Public use file building identifier
# 1                                     Census Region
# 2                                   Census division
# 3                       Principal building activity
# 4                                    Square footage
# ..                                              ...
# 556                             Tinted window glass
# 557                         Reflective window glass
# 558                   External overhangs or awnings
# 559  Skylights or atriums designed to provide light
# 560                                Percent daylight
#
#                                                  codes  \
# 0                                        00001 - 06436
# 1              1=Northeast\n2=Midwest\n3=South\n4=West
# 2    1=New England\n2=Middle Atlantic  \n3=East Nor...
# 3    1=Vacant\n2=Office\n4=Laboratory\n5=Nonrefrige...
# 4                                    1,001 - 2,100,000
# ..                                                 ...
# 556                1=Yes\n2=No\nMissing=Not applicable
# 557                1=Yes\n2=No\nMissing=Not applicable
# 558                1=Yes\n2=No\nMissing=Not applicable
# 559                1=Yes\n2=No\nMissing=Not applicable
# 560                    0 - 100\nMissing=Not applicable
#
#                                             codes_dict
# 0      {'00001 - 06436': 'continuous numerical range'}
# 1    {'1': 'Northeast', '2': 'Midwest', '3': 'South...
# 2    {'1': 'New England', '2': 'Middle Atlantic', '...
# 3    {'1': 'Vacant', '2': 'Office', '4': 'Laborator...
# 4    {'1,001 - 2,100,000': 'continuous numerical ra...
# ..                                                 ...
# 556  {'1': 'Yes', '2': 'No', 'Missing': 'Not applic...
# 557  {'1': 'Yes', '2': 'No', 'Missing': 'Not applic...
# 558  {'1': 'Yes', '2': 'No', 'Missing': 'Not applic...
# 559  {'1': 'Yes', '2': 'No', 'Missing': 'Not applic...
# 560  {'0 - 100': 'continuous numerical range', 'Mis...
#
# [561 rows x 8 columns]

# %%
new_codebook.to_csv('2018cbecs_codebook_wDicts.csv', index=False)
