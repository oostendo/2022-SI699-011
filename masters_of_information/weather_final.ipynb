# %%
import pandas as pd
import altair as alt
import os
from sklearn.metrics import r2_score

# %%
cd Daiwei\ 2
# Out:
# [Errno 2] No such file or directory: 'Daiwei 2'
# /Users/katiechenning/Documents/umich/courses/si699/Daiwei 2

# %% [markdown]
# # Dry data

# %%
df = pd.read_csv('USDM.csv')

# %%
df
# Out:
#        MapDate AreaOfInterest   None     D0     D1     D2     D3    D4  \
# 0     20220118          Total  40.65  59.35  45.99  30.08   9.43  1.00
# 1     20220111          Total  39.92  60.08  45.96  29.53   9.60  1.03
# 2     20220104          Total  39.91  60.09  45.82  29.35  10.33  1.30
# 3     20211228          Total  38.50  61.50  46.23  30.30  11.70  1.59
# 4     20211221          Total  39.37  60.63  46.17  30.67  14.68  3.07
# ...        ...            ...    ...    ...    ...    ...    ...   ...
# 1146  20000201          Total  45.60  54.40  24.29   8.53   0.00  0.00
# 1147  20000125          Total  42.03  57.97  21.39   8.45   0.00  0.00
# 1148  20000118          Total  43.26  56.74  21.75   8.67   0.00  0.00
# 1149  20000111          Total  48.27  51.73  20.93   8.27   0.00  0.00
# 1150  20000104          Total  57.29  42.71  19.61   7.90   0.00  0.00
#
#       ValidStart    ValidEnd  StatisticFormatID
# 0     2022-01-18  2022-01-24                  1
# ...

# %%
# D0 - Abnormally Dry
# Short-term dryness slowing planting, growth of crops or pastures.
# Some lingering water deficits
# Pastures or crops not fully recovered
# D1 - Moderate Drought
# Some damage to crops, pastures
# Streams, reservoirs, or wells low, some water shortages developing or imminent
# Voluntary water-use restrictions requested
# D2 - Severe Drought
# Crop or pasture loss likely
# Water shortages common
# Water restrictions imposed
# D3 - Extreme Drought
# Major crop/pasture losses
# Widespread water shortages or restrictions
# D4 - Exceptional Drought
# Exceptional and widespread crop/pasture losses
# Shortages of water in reservoirs, streams, and wells creating water emergencies

# %% [markdown]
# # single station in Michigan

# %%
# single station 

#df2 = pd.read_csv('single_station.csv')

# %%
#df2

# %%
#df2.columns.tolist()

# %%
# df2['DATE'] = pd.to_datetime(df2['DATE'])
# df2

# %%
# l = [i.round(freq='H').hour for i in data_after['DATE']]
# l_2  = [i.round(freq='H').dayofweek for i in data_after['DATE']]
# l_3 = [i.round(freq='H').day for i in data_after['DATE']]
# l_4 = [i.round(freq='H').month for i in data_after['DATE']]

# %%
pd.set_option('display.max_columns', None)

# %%
df3 = pd.read_csv('2021_2022.csv')

# %%
df3
# Out:
#          STATION                              NAME  DATE  AWND   CDSD   DSND  \
# 0    US1MICP0014     SAULT STE. MARIE 2.2 E, MI US  2021   NaN    NaN    NaN
# 1    USC00203429           GREENVILLE 2 NNE, MI US  2021   NaN    NaN    NaN
# 2    USC00200718               BERGLAND DAM, MI US  2021   NaN    NaN    NaN
# 3    USC00200032               ADRIAN 2 NNE, MI US  2021   NaN    NaN   33.0
# 4    USC00201486  CHATHAM EXPERIMENT FARM 2, MI US  2021   NaN    NaN  111.0
# ..           ...                               ...   ...   ...    ...    ...
# 267  USC00202094             DETOUR VILLAGE, MI US  2021   NaN  270.0   95.0
# 268  US1MIKN0016       GRAND RAPIDS 2.5 ENE, MI US  2021   NaN    NaN    NaN
# 269  US1MIKN0014         GRANDVILLE 1.3 WSW, MI US  2021   NaN    NaN   65.0
# 270  USC00203188               GLENNIE 2 SE, MI US  2021   NaN  390.0   88.0
# 271  US1MIKN0011             LOWELL 1.4 ESE, MI US  2021   NaN    NaN    NaN
#
# ...

# %%
df3 = df3.dropna()

# %%
df3
# Out:
# Empty DataFrame
# Columns: [STATION, NAME, DATE, AWND, CDSD, DSND, DSNW, EMNT, EMSD, EMSN, EMXP, EMXT, HDSD, HN01, HN02, HX01, HX02, LN01, LN02, LX01, LX02, MN01, MN02, MX01, MX02, PRCP, SNOW, TAVG, TMAX, TMIN, WDF2, WDF5, WDFG, WDMV, WSF2, WSF5, WSFG]
# Index: []

# %%
LocationList = ['BAD AXE, MI US', 'KALAMAZOO BATTLE CREEK INTERNATIONAL AIRPORT, MI US', 'GREENVILLE 2 NNE, MI US', 'CARO WWTP, MI US', 'HOLLAND, MI US']
df_filtered = df3[df3['NAME'].isin(LocationList)]
#'BAD AXE, MI US', KALAMAZOO BATTLE CREEK INTERNATIONAL AIRPORT, MI US', 'GREENVILLE 2 NNE, MI US', 'CARO WWTP, MI US', 'HOLLAND, MI US'

# %%
df_filtered
# Out:
# Empty DataFrame
# Columns: [STATION, NAME, DATE, AWND, CDSD, DSND, DSNW, EMNT, EMSD, EMSN, EMXP, EMXT, HDSD, HN01, HN02, HX01, HX02, LN01, LN02, LX01, LX02, MN01, MN02, MX01, MX02, PRCP, SNOW, TAVG, TMAX, TMIN, WDF2, WDF5, WDFG, WDMV, WSF2, WSF5, WSFG]
# Index: []

# %%
df3.columns.tolist()
# Out:
# ['STATION',
#  'NAME',
#  'DATE',
#  'AWND',
#  'CDSD',
#  'DSND',
#  'DSNW',
#  'EMNT',
#  'EMSD',
#  'EMSN',
#  'EMXP',
#  'EMXT',
#  'HDSD',
#  'HN01',
#  'HN02',
#  'HX01',
#  'HX02',
#  'LN01',
#  'LN02',
#  'LX01',
#  'LX02',
#  'MN01',
#  'MN02',
#  'MX01',
#  'MX02',
#  'PRCP',
#  'SNOW',
#  'TAVG',
#  'TMAX',
#  'TMIN',
#  'WDF2',
#  'WDF5',
#  'WDFG',
#  'WDMV',
#  'WSF2',
#  'WSF5',
#  'WSFG']

# %%
# EMXP - Extreme maximum precipitation for the period.
# EMXT - Extreme maximum temperature for the period.
# MN01 - Monthly mean minimum soil temperature (degrees F)
# MN02 - Monthly mean minimum soil temperature (degrees F)
# MX01 - Monthly mean maximum soil temperature (degrees F)
# MX02 - Monthly mean maximum soil temperature (degrees F)
# PRCP - Precipitation
# EMNT - Extreme minimum temperature for the period.
# WDF2 - Direction of fastest 2-minute wind
# WDF5 - Direction of fastest 5-second wind
# TMAX - Maximum temperature
# EMSD - Extreme maximum snow depth for the period.
# WDMV - Total wind movement
# LN01 - Lowest minimum soil temperature for the month (degrees F)
# WSF2 - Fastest 2-minute wind speed
# EMSN - Extreme maximum snowfall for the period.
# WSF5 - Fastest 5-second wind speed
# DSND - Number days with snow depth > 1 inch(25.4mm) for the period.
# SNOW - Snowfall
# HN01 - Highest minimum soil temperature for the month (degrees F)
# WDFG - Direction of peak wind gust
# LN02 - Lowest minimum soil temperature for the month (degrees F)
# HN02 - Highest minimum soil temperature for the month (degrees F)
# HDSD - Heating Degree Days Season to Date
# LX02 - Lowest maximum soil temperature for the month (degrees F)
# CDSD - Cooling Degree Days Season to Date
# LX01 - Lowest maximum soil temperature for the month (degrees F)
# HX02 - Highest maximum soil temperature for the month (degrees F)
# AWND - Average wind speed
# HX01 - Highest maximum soil temperature for the month (degrees F)
# WSFG - Peak gust wind speed
# DSNW - Number days with snow depth > 1 inch.
# TAVG - Average Temperature.
# TMIN - Minimum temperature

# %%
#df3[df3["DATE"]==2021].mean(axis=0)

# %%
df3[df3["DATE"]==2021].mean(axis=0).to_frame().T
# Out:
#    STATION  NAME  DATE  AWND  CDSD  DSND  DSNW  EMNT  EMSD  EMSN  EMXP  EMXT  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    HDSD  HN01  HN02  HX01  HX02  LN01  LN02  LX01  LX02  MN01  MN02  MX01  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    MX02  PRCP  SNOW  TAVG  TMAX  TMIN  WDF2  WDF5  WDFG  WDMV  WSF2  WSF5  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WSFG
# 0   NaN

# %%
df3[df3["DATE"]==2021].median(axis=0).to_frame().T
# Out:
#    STATION  NAME  DATE  AWND  CDSD  DSND  DSNW  EMNT  EMSD  EMSN  EMXP  EMXT  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    HDSD  HN01  HN02  HX01  HX02  LN01  LN02  LX01  LX02  MN01  MN02  MX01  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    MX02  PRCP  SNOW  TAVG  TMAX  TMIN  WDF2  WDF5  WDFG  WDMV  WSF2  WSF5  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WSFG
# 0   NaN

# %%
df3[df3["DATE"]==2021].median(axis=0).to_frame().T
# Out:
#    STATION  NAME  DATE  AWND  CDSD  DSND  DSNW  EMNT  EMSD  EMSN  EMXP  EMXT  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    HDSD  HN01  HN02  HX01  HX02  LN01  LN02  LX01  LX02  MN01  MN02  MX01  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    MX02  PRCP  SNOW  TAVG  TMAX  TMIN  WDF2  WDF5  WDFG  WDMV  WSF2  WSF5  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WSFG
# 0   NaN

# %% [markdown]
# ## Model

# %%
import os

os.getcwd()
# Out:
# '/Users/katiechenning/Documents/umich/courses/si699/Daiwei 2'

# %%
# for root, dirs, files in os.walk(""):
#     for file in files:
#         if file.endswith('.csv'):
#             print(file)

# %%
for root, dirs, files in os.walk("."):
    print(root, dirs, files)
# Out:
# . ['.ipynb_checkpoints'] ['weather 6.ipynb', 'YieldData.ipynb', 'weather 12.ipynb', 'cabbage.csv', 'peppers.csv', 'weather 10.ipynb', 'weather 4.ipynb', 'carrots.csv', '.DS_Store', 'cucumbers.csv', 'weather 14.ipynb', 'geo_json_data.json', 'weather 16.ipynb', 'weather 2.ipynb', '2008.csv', 'weather 11.ipynb', '2020.csv', 'weather 5.ipynb', '2009.csv', 'USDM.csv', 'weather 7.ipynb', 'weather 13.ipynb', 'weather 17.ipynb', 'weather 3.ipynb', '2019.csv', 'fig1.jpeg', 'weather 15.ipynb', '2018.csv', 'weather.ipynb', '2015.csv', 'weather 19.ipynb', '2014.csv', 'pumpkins.csv', '2016.csv', '2017.csv', '2013.csv', '2021_2022.csv', '2007.csv', 'Asparagus.csv', 'weather 22.ipynb', 'single_station.csv', '2006.csv', '2012.csv', '2010.csv', 'weather 9.ipynb', 'weather 20.ipynb', '2011.csv', 'tomatoes.csv', 'onions.csv', 'weather 18.ipynb', 'weather_final.ipynb', 'weather 8.ipynb', 'squah.csv', 'potato.csv', 'weather 21.ipynb', 'corn.csv', 'weather 23.ipynb']
# ...

# %%
\
all_csvs = []

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith('.csv') and (file.startswith('2') or file.startswith('1')):
            
            all_csvs.append(file)

# %%
all_csvs
# Out:
# ['2008.csv',
#  '2020.csv',
#  '2009.csv',
#  '2019.csv',
#  '2018.csv',
#  '2015.csv',
#  '2014.csv',
#  '2016.csv',
#  '2017.csv',
#  '2013.csv',
#  '2021_2022.csv',
#  '2007.csv',
#  '2006.csv',
#  '2012.csv',
#  '2010.csv',
#  '2011.csv']

# %%
df_all = pd.DataFrame()
for i in all_csvs:
    df_all = pd.concat([pd.read_csv(i), df_all],  join='outer' )
    df_all = df_all[df_all['NAME'].isin(LocationList)]
df_all = df_all.groupby(by='DATE').median().drop(columns=['PSUN','TSUN'], index=[2021, 2022])

# %%
df_all
# Out:
#       LATITUDE  LONGITUDE  ELEVATION  AWND   CDSD   CLDD   DP01  DP10   DSND  \
# DATE
# 2006   43.2026   -85.2421      217.9   7.6  604.0  604.0  140.0  81.0   39.0
# 2007   43.3432   -84.3170      240.6   7.6  751.0  751.0  138.0  69.0   93.0
# 2008   43.2026   -85.2421      217.9   7.6  449.5  449.5  143.5  93.0  106.0
# 2009   43.2026   -85.2421      217.9   7.4  280.5  280.5  139.5  71.5   65.0
# 2010   43.2026   -85.2421      217.9   7.2  722.5  722.5  118.0  61.5   72.0
# 2011   43.2026   -85.2421      217.9   7.4  626.0  626.0  143.0  78.5   75.0
# 2012   43.2026   -85.2421      217.9   7.4  757.0  757.0  129.0  70.0    NaN
# 2013   43.2026   -85.2421      217.9   7.4  518.0  518.0  152.0  81.5    NaN
# 2014       NaN        NaN        NaN   8.1  466.5  466.5  152.0  70.0    NaN
# 2015       NaN        NaN        NaN   7.8  487.5  487.5  136.5  70.0    NaN
# 2016       NaN        NaN        NaN   7.6  708.5  708.5  137.5  71.0   64.0
# ...

# %%
pd.options.display.max_columns = None
df_all = df_all.dropna(axis='columns', how='any')
df_all
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
# 2016   7.6  708.5  708.5  137.5  71.0   6.0  141.5  45.0  145.0  10.5  -7.0
# ...

# %%
# test with data 
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
# Select one row randomly using sample()
# without give any parameters
X_test_set = df_all.sample(n=3, random_state=42)
X_test_set
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
# 2017   7.8  539.0  539.0  144.5  75.0   4.5  131.5  45.5  145.0  11.0 -10.5
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# 2015  2.060  90.0  7722.5  7722.5  32.915  46.75  57.75  35.65  320.0  38.0
# 2017  3.125  93.5  6080.5  6080.5  38.840  48.45  59.30  39.00  290.0  40.9
# 2006  2.100  95.5  5853.0  5853.0  37.630  49.95  60.10  39.85  220.0  36.9

# %%
X_train_set = df_all.drop(index=X_test_set.index)

yPumpkin = pd.read_csv("pumpkins.csv", thousands=',')
yPumpkin = yPumpkin[(yPumpkin['Year'] >= df_all.index[0]) & (yPumpkin['Year'] <= df_all.index[-1])].set_index('Year')
yPumpkin = yPumpkin[['Value']]
yPumpkin_train_set = yPumpkin.drop(index=X_test_set.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
yPumpkin_test_set = yPumpkin[yPumpkin.index.isin(X_test_set.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']


X_train_set = scaler.fit_transform(X_train_set)
X_test_set = scaler.transform(X_test_set)

X_train_set
# Out:
# array([[ 0.25890435,  1.07662255,  1.07662255, -0.28606166, -0.72560104,
#          0.24594698, -0.59278531,  0.69324293,  2.45890459,  1.03718375,
#         -0.95827494, -1.43236533,  0.74612401, -0.69115457, -0.69115457,
#         -1.08048449,  0.43608063,  0.94040019, -0.1681365 , -1.53434219,
#          2.28787415],
#        [ 0.25890435, -1.0086132 , -1.0086132 ,  0.21740686,  2.04225459,
#         -0.11179408,  0.42341808,  0.69324293,  0.04703991, -1.26766902,
#          0.43806854,  1.15780705, -1.24354001,  0.09107579,  0.09107579,
#          1.48526964, -0.86403553, -0.69113749, -0.87430981, -0.83514828,
#          0.7138571 ],
#        [-0.62876771, -2.17745181, -2.17745181, -0.14875206, -0.43728275,
#          0.51425278,  0.02822787,  0.69324293, -1.69771326, -1.11401217,
#         -0.95827494,  0.82626499,  0.        ,  0.85713381,  0.85713381,
#         -0.27780261, -1.12405877, -0.77271437, -1.34509201,  0.09711027,
#         -1.10231643],
# ...

# %%
yPumpkin
# Out:
#       Value
# Year
# 2020    160
# 2019    150
# 2018    190
# 2017    155
# 2016    155
# 2015    155
# 2014    160
# 2013    155
# 2012    150
# 2011    145
# 2010    140
# 2009    110
# 2008    145
# 2007    115
# 2006    150

# %%
X_test_set
# Out:
# array([[ 1.14657642, -0.74579742, -0.74579742, -0.42337126, -0.61027372,
#          3.28674604, -0.87506403,  0.14594588,  0.14967245, -1.34449745,
#         -2.68316982, -0.06475431, -2.23837202,  1.42146322,  1.42146322,
#         -0.34849953, -0.31148616, -0.06571471, -1.34509201,  1.26243345,
#         -0.76935129],
#        [ 1.14657642, -0.38961287, -0.38961287,  0.3089466 , -0.03363713,
#         -0.55897042, -2.11709039, -0.7297294 ,  0.9194165 , -0.03841421,
#         -0.38330997,  2.14207256, -0.497416  , -1.37379739, -1.37379739,
#          0.94035958,  0.79361257,  0.77724642,  0.90793711,  0.56323954,
#          0.10846592],
#        [ 0.25890435,  0.05994044,  0.05994044, -0.1029822 ,  0.65832677,
#         -1.18501728, -1.77835593, -2.44459348,  0.25230499,  0.26889949,
#          1.09517136,  0.01813121,  0.497416  , -1.76108228, -1.76108228,
#          0.67714954,  1.7686997 ,  1.21232314,  1.47960121, -1.06821292,
#         -1.10231643]])

# %%
yPumpkin_train_set
# Out:
# 11    115
# 10    145
# 9     110
# 8     140
# 7     145
# 6     150
# 5     155
# 4     160
# 3     155
# 2     190
# 1     150
# 0     160
# Name: Value, dtype: int64

# %%
yPumpkin_test_set
# Out:
# 2    150
# 1    155
# 0    155
# Name: Value, dtype: int64

# %%
X_test_set
# Out:
# array([[ 1.14657642, -0.74579742, -0.74579742, -0.42337126, -0.61027372,
#          3.28674604, -0.87506403,  0.14594588,  0.14967245, -1.34449745,
#         -2.68316982, -0.06475431, -2.23837202,  1.42146322,  1.42146322,
#         -0.34849953, -0.31148616, -0.06571471, -1.34509201,  1.26243345,
#         -0.76935129],
#        [ 1.14657642, -0.38961287, -0.38961287,  0.3089466 , -0.03363713,
#         -0.55897042, -2.11709039, -0.7297294 ,  0.9194165 , -0.03841421,
#         -0.38330997,  2.14207256, -0.497416  , -1.37379739, -1.37379739,
#          0.94035958,  0.79361257,  0.77724642,  0.90793711,  0.56323954,
#          0.10846592],
#        [ 0.25890435,  0.05994044,  0.05994044, -0.1029822 ,  0.65832677,
#         -1.18501728, -1.77835593, -2.44459348,  0.25230499,  0.26889949,
#          1.09517136,  0.01813121,  0.497416  , -1.76108228, -1.76108228,
#          0.67714954,  1.7686997 ,  1.21232314,  1.47960121, -1.06821292,
#         -1.10231643]])

# %%
reg = LinearRegression()

reg.fit(X_train_set, yPumpkin_train_set)
reg.score(X_train_set, yPumpkin_train_set)
# Out:
# 1.0

# %%
reg.score(X_test_set, yPumpkin_test_set)
# Out:
# -66.64782060458961

# %%
Pumpkin_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set, yPumpkin_train_set)
reg.score(X_train_set, yPumpkin_train_set)
# Out:
# 1.0

# %%
Pumpkin_DT.score(X_test_set, yPumpkin_test_set)
# Out:
# -102.49999999999999

# %%
# mean_absolute_error(y_test_set.to_list(), reg.predict(X_test_set))

# %%
pumpkin_y_test_pred = Pumpkin_DT.predict(X_test_set)

# %%
pumpkin_y_test_pred
# Out:
# array([110., 145., 150.])

# %%
yPumpkin_test_set.to_list()
# Out:
# [150, 155, 155]

# %%
from sklearn.metrics import mean_absolute_error
pumpkin_mae_reg = mean_absolute_error(yPumpkin_test_set.to_list(), reg.predict(X_test_set))
pumpkin_mae_dt = mean_absolute_error(yPumpkin_test_set.to_list(), Pumpkin_DT.predict(X_test_set))

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

folds = 6

scalar = StandardScaler()
clf = LinearRegression()

pipeline = Pipeline([('transformer', scalar), ('estimator', clf)])

cv = KFold(n_splits=(folds - 1))
scores = cross_val_score(pipeline, df_all, yPumpkin, cv = cv, scoring='r2')

# %%
round(scores.mean())
# Out:
# -9

# %%
scores
# Out:
# array([ -7.37539437,   0.        , -29.53201782,  -3.00216974,
#         -4.91995871])

# %%
pumpkin_r2_score = r2_score(yPumpkin_test_set, pumpkin_y_test_pred)

# %%
pumpkin_r2_score
# Out:
# -102.49999999999999

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

folds = 6

scalar = StandardScaler()
clf = DecisionTreeRegressor(random_state=0)

pipeline = Pipeline([('transformer', scalar), ('estimator', clf)])

cv = KFold(n_splits=(folds - 1))
scores = cross_val_score(pipeline, df_all, yPumpkin, cv = cv, scoring='neg_mean_absolute_error')

# %%
round(scores.mean())
# Out:
# -23

# %%
scores
# Out:
# array([-28.33333333, -16.66666667, -30.        , -26.66666667,
#        -15.        ])

# %%
Pumpkin_RF_classifier = RandomForestClassifier(random_state=0).fit(X_train_set, yPumpkin_train_set)

# %%
Pumpkin_RF_classifier.score(X_train_set, yPumpkin_train_set)
#test_score_RF = RF_classifier.score(X_test, y_test)
# Out:
# 1.0

# %%
Pumpkin_RF_classifier.score(X_test_set, yPumpkin_test_set)
# Out:
# 0.3333333333333333

# %% [markdown]
# ## Onions

# %%
yOnion1 = pd.read_csv("onions.csv", thousands=',')

# %%
yOnion1
# Out:
#     Year  Value
# 0   2015    330
# 1   2014    370
# 2   2013    300
# 3   2012    230
# 4   2011    240
# 5   2010    220
# 6   2009    350
# 7   2008    280
# 8   2007    260
# 9   2006    250
# 10  2005    260
# 11  2004    290
# 12  2003    320
# 13  2002    230
# 14  2001    270
# 15  2000    270
# 16  1999    270
# 17  1998    260

# %%
df_all
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
# 2016   7.6  708.5  708.5  137.5  71.0   6.0  141.5  45.0  145.0  10.5  -7.0
# ...

# %%
df_all_onion = df_all.loc[2006:2015]

# %%
df_all_onion
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# ...

# %%
X_test_set_onion = df_all_onion.sample(n=3, random_state=42)
X_test_set_onion
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX  TMIN   WDF2  WSF2
# DATE
# 2014  1.510  90.5  7919.0  7919.0  30.105  45.05  54.25  35.8  280.0  46.1
# 2007  1.400  96.0  6481.5  6481.5  29.550  47.90  59.60  37.4  200.0  48.1
# 2011  1.905  96.0  7396.0  7396.0  38.265  47.20  59.00  38.0  300.0  38.0

# %%
X_train_set_onion = df_all_onion.drop(index=X_test_set_onion.index)

# %%
yOnion = yOnion1[(yOnion1['Year'] >= df_all.index[0]) & (yOnion1['Year'] <= df_all.index[-1])].set_index('Year')
yOnion = yOnion[['Value']]
yOnion_train_set = yOnion.drop(index=X_test_set_onion.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
yOnion_test_set = yOnion[yOnion.index.isin(X_test_set_onion.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
yOnion_train_set
# Out:
# 6    250
# 5    280
# 4    350
# 3    220
# 2    230
# 1    300
# 0    330
# Name: Value, dtype: int64

# %%
yOnion_test_set
# Out:
# 2    260
# 1    240
# 0    370
# Name: Value, dtype: int64

# %%
onion_scaler = StandardScaler()

# %%
X_train_set_onion = onion_scaler.fit_transform(X_train_set_onion)
X_test_set_onion = onion_scaler.transform(X_test_set_onion)

X_train_set_onion
# Out:
# array([[ 0.63245553,  0.38284319,  0.38284319,  0.3054643 ,  0.57296996,
#         -0.76976516, -1.40661333, -1.87421222,  0.51255614,  0.66082793,
#          0.63448132, -0.33653828,  0.4664981 , -1.33110459, -1.33110459,
#          0.5901593 ,  1.31146139,  1.20350506,  1.16059325, -0.86379214,
#         -0.98625381],
#        [ 0.63245553, -0.62949155, -0.62949155,  0.65355152,  1.82308623,
#         -0.05131768,  0.92069236,  0.74968489,  0.21356506, -0.96225821,
#          0.17304036,  0.8050233 , -0.87811408,  0.27296069,  0.27296069,
#          1.34302133, -0.87559334, -0.85125967, -0.65052361, -0.63123272,
#          1.93083492],
#        [-0.47434165, -1.73683506, -1.73683506,  0.25573755, -0.41670542,
#          0.36777669,  0.50297083,  0.74968489, -2.32785914, -0.7999496 ,
#         -0.80752167,  0.47293266,  0.08232319,  0.93640681,  0.93640681,
#         -0.29949463, -1.09159874, -0.93932102, -1.01274698,  0.29900497,
#         -0.98625381],
# ...

# %%
onion_reg = LinearRegression()

onion_reg.fit(X_train_set_onion, yOnion_train_set)
onion_reg.score(X_train_set_onion, yOnion_train_set)
# Out:
# 1.0

# %%
onion_reg.score(X_test_set_onion, yOnion_test_set)
# Out:
# -0.24089196816479563

# %%
Onion_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set_onion, yOnion_train_set)
Onion_DT.score(X_train_set_onion, yOnion_train_set)
# Out:
# 1.0

# %%
Onion_DT.score(X_test_set_onion, yOnion_test_set)
# Out:
# 0.41836734693877553

# %%
onion_y_test_pred = Onion_DT.predict(X_test_set_onion)

# %%
onion_r2_score = r2_score(yOnion_test_set, onion_y_test_pred)

# %%
onion_r2_score
# Out:
# 0.41836734693877553

# %%
yOnion_test_set.to_list()
# Out:
# [260, 240, 370]

# %%
onion_mae_reg = mean_absolute_error(yOnion_test_set.to_list(), onion_reg.predict(X_test_set_onion))
onion_mae_dt = mean_absolute_error(yOnion_test_set.to_list(), Onion_DT.predict(X_test_set_onion))

# %%
folds = 6

onion_scalar2 = StandardScaler()
Onion_clf = LinearRegression()

onion_pipeline = Pipeline([('transformer', onion_scalar2), ('estimator', Onion_clf)])

cv = KFold(n_splits=(folds - 1))
onion_scores = cross_val_score(onion_pipeline, df_all_onion, yOnion, cv = cv, scoring='r2')

# %%
round(onion_scores.mean())
# Out:
# -25

# %%
folds = 6

onnion_DTscalar = StandardScaler()
OnionDTclf = DecisionTreeRegressor(random_state=0)

OnionDTpipeline = Pipeline([('transformer', onnion_DTscalar), ('estimator', OnionDTclf)])

cv = KFold(n_splits=(folds - 1))
onion_dt_scores = cross_val_score(OnionDTpipeline, df_all_onion, yOnion, cv = cv, scoring='neg_mean_absolute_error')

# %%
round(onion_dt_scores.mean())
# Out:
# -47

# %%
#Onion_RF_classifier = RandomForestClassifier(random_state=0).fit(X_train_set_onion, yPumpkin_train_set)

# %% [markdown]
# ## Asparagus

# %%
yasparagus1 = pd.read_csv("Asparagus.csv", thousands=',')

# %%
yasparagus1
# Out:
#     Unnamed: 0  Year  Value
# 0         8881  2020     28
# 1         9024  2019     30
# 2         9183  2018     28
# 3         9337  2018     28
# 4         9408  2017     27
# 5         9561  2017     27
# 6         9639  2016     25
# 7         9860  2015     26
# 8        10028  2014     24
# 9        10207  2013     23
# 10       10381  2012     21
# 11       10558  2011     22
# 12       10746  2010     16
# 13       10872  2010     16
# 14       10929  2009     22
# 15       11103  2008     23
# 16       11286  2007     21
# 17       11473  2006     22
# 18       11658  2005     19
# 19       11831  2004     20
# 20       12013  2003     21
# 21       12193  2002     15
# 22       12372  2001     20
# 23       12529  2000     17
# 24       12684  1999     18
# 25       12816  1998     16

# %%
df_all_asparagus = df_all.loc[2006:2020]

# %%
df_all_asparagus
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
# 2016   7.6  708.5  708.5  137.5  71.0   6.0  141.5  45.0  145.0  10.5  -7.0
# ...

# %%
X_test_set_asparagus = df_all.sample(n=3, random_state=42)
X_test_set_asparagus
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
# 2017   7.8  539.0  539.0  144.5  75.0   4.5  131.5  45.5  145.0  11.0 -10.5
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# 2015  2.060  90.0  7722.5  7722.5  32.915  46.75  57.75  35.65  320.0  38.0
# 2017  3.125  93.5  6080.5  6080.5  38.840  48.45  59.30  39.00  290.0  40.9
# 2006  2.100  95.5  5853.0  5853.0  37.630  49.95  60.10  39.85  220.0  36.9

# %%
X_train_set_asparagus = df_all.drop(index=X_test_set_asparagus.index)

# %%
X_train_set_asparagus
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2016   7.6  708.5  708.5  137.5  71.0   6.0  141.5  45.0  145.0  10.5  -7.0
# 2018   7.4  700.5  700.5  152.0  81.0   7.5  168.5  50.0  137.0  17.0  -9.0
# 2019   7.8  492.0  492.0  157.5  87.5  14.0  153.0  55.5  131.5   7.0 -18.0
# ...

# %%
yAsparagus = yasparagus1[(yasparagus1['Year'] >= df_all_asparagus.index[0]) & (yasparagus1['Year'] <= df_all_asparagus.index[-1])].set_index('Year')
yAsparagus = yAsparagus[['Value']]

# %%
yAsparagus
# Out:
#       Value
# Year
# 2020     28
# 2019     30
# 2018     28
# 2018     28
# 2017     27
# 2017     27
# 2016     25
# 2015     26
# 2014     24
# 2013     23
# 2012     21
# 2011     22
# 2010     16
# 2010     16
# 2009     22
# 2008     23
# 2007     21
# 2006     22

# %%
yAsparagus = yAsparagus[~yAsparagus.index.duplicated(keep='first')]

# %%
yAsparagus
# Out:
#       Value
# Year
# 2020     28
# 2019     30
# 2018     28
# 2017     27
# 2016     25
# 2015     26
# 2014     24
# 2013     23
# 2012     21
# 2011     22
# 2010     16
# 2009     22
# 2008     23
# 2007     21
# 2006     22

# %%
yAsparagus_train_set = yAsparagus.drop(index=X_test_set_asparagus.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
yAsparagus_test_set = yAsparagus[yAsparagus.index.isin(X_test_set_asparagus.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
yAsparagus_test_set
# Out:
# 2    22
# 1    26
# 0    27
# Name: Value, dtype: int64

# %%
yAsparagus_train_set
# Out:
# 11    21
# 10    23
# 9     22
# 8     16
# 7     22
# 6     21
# 5     23
# 4     24
# 3     25
# 2     28
# 1     30
# 0     28
# Name: Value, dtype: int64

# %%
asparagus_scaler = StandardScaler()
X_train_set_asparagus = asparagus_scaler.fit_transform(X_train_set_asparagus)
X_test_set_asparagus = asparagus_scaler.transform(X_test_set_asparagus)

X_test_set_asparagus
# Out:
# array([[ 1.14657642, -0.74579742, -0.74579742, -0.42337126, -0.61027372,
#          3.28674604, -0.87506403,  0.14594588,  0.14967245, -1.34449745,
#         -2.68316982, -0.06475431, -2.23837202,  1.42146322,  1.42146322,
#         -0.34849953, -0.31148616, -0.06571471, -1.34509201,  1.26243345,
#         -0.76935129],
#        [ 1.14657642, -0.38961287, -0.38961287,  0.3089466 , -0.03363713,
#         -0.55897042, -2.11709039, -0.7297294 ,  0.9194165 , -0.03841421,
#         -0.38330997,  2.14207256, -0.497416  , -1.37379739, -1.37379739,
#          0.94035958,  0.79361257,  0.77724642,  0.90793711,  0.56323954,
#          0.10846592],
#        [ 0.25890435,  0.05994044,  0.05994044, -0.1029822 ,  0.65832677,
#         -1.18501728, -1.77835593, -2.44459348,  0.25230499,  0.26889949,
#          1.09517136,  0.01813121,  0.497416  , -1.76108228, -1.76108228,
#          0.67714954,  1.7686997 ,  1.21232314,  1.47960121, -1.06821292,
#         -1.10231643]])

# %%
asparagus_reg = LinearRegression()

asparagus_reg.fit(X_train_set_asparagus, yAsparagus_train_set)
asparagus_reg.score(X_train_set_asparagus, yAsparagus_train_set)
# Out:
# 1.0

# %%
asparagus_reg.score(X_test_set_asparagus, yAsparagus_test_set)
# Out:
# -1.9487223514578318

# %%
Asparagus_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set_asparagus, yAsparagus_train_set)
Asparagus_DT.score(X_train_set_asparagus, yAsparagus_train_set)
# Out:
# 1.0

# %%
Asparagus_DT.score(X_test_set_asparagus, yAsparagus_test_set)
# Out:
# -0.8571428571428572

# %%
asparagus_mae_dt = mean_absolute_error(yAsparagus_test_set.to_list(), Asparagus_DT.predict(X_test_set_asparagus))
asparagus_mae_reg = mean_absolute_error(yAsparagus_test_set.to_list(), asparagus_reg.predict(X_test_set_asparagus))

# %%
asparagus_y_test_pred = Asparagus_DT.predict(X_test_set_asparagus)

# %% [markdown]
# ## Peppers

# %%
ypeppers1 = pd.read_csv("peppers.csv", thousands=',')

# %%
ypeppers1
# Out:
#     Year  Value
# 0   2020    230
# 1   2019    255
# 2   2018    240
# 3   2017    255
# 4   2016    260
# 5   2015    280
# 6   2014    260
# 7   2013    250
# 8   2012    260
# 9   2011    270
# 10  2010    230
# 11  2009    240
# 12  2008    250
# 13  2007    260
# 14  2006    270
# 15  2005    280
# 16  2004    290
# 17  2003    250
# 18  2002    250
# 19  2001    260
# 20  2000    220
# 21  1999    200
# 22  1998    200

# %%
df_all_peppers = df_all.loc[2006:2020]

# %%
X_test_set_peppers = df_all_peppers.sample(n=3, random_state=42)
X_test_set_peppers
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
# 2017   7.8  539.0  539.0  144.5  75.0   4.5  131.5  45.5  145.0  11.0 -10.5
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# 2015  2.060  90.0  7722.5  7722.5  32.915  46.75  57.75  35.65  320.0  38.0
# 2017  3.125  93.5  6080.5  6080.5  38.840  48.45  59.30  39.00  290.0  40.9
# 2006  2.100  95.5  5853.0  5853.0  37.630  49.95  60.10  39.85  220.0  36.9

# %%
X_train_setpeppers = df_all_peppers.drop(index=X_test_set_peppers.index)

# %%
yPeppers = ypeppers1[(ypeppers1['Year'] >= df_all_peppers.index[0]) & (ypeppers1['Year'] <= df_all_peppers.index[-1])].set_index('Year')
yPeppers = yPeppers[['Value']]
yPeppers_train_set = yPeppers.drop(index=X_test_set_peppers.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
yPeppers_test_set = yPeppers[yPeppers.index.isin(X_test_set_peppers.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
yPeppers
# Out:
#       Value
# Year
# 2020    230
# 2019    255
# 2018    240
# 2017    255
# 2016    260
# 2015    280
# 2014    260
# 2013    250
# 2012    260
# 2011    270
# 2010    230
# 2009    240
# 2008    250
# 2007    260
# 2006    270

# %%
yPeppers_test_set
# Out:
# 2    270
# 1    280
# 0    255
# Name: Value, dtype: int64

# %%
yPeppers_train_set
# Out:
# 11    260
# 10    250
# 9     240
# 8     230
# 7     270
# 6     260
# 5     250
# 4     260
# 3     260
# 2     240
# 1     255
# 0     230
# Name: Value, dtype: int64

# %%
peppers_scaler = StandardScaler()

# %%
X_train_setpeppers = peppers_scaler.fit_transform(X_train_setpeppers)
X_test_set_peppers = peppers_scaler.transform(X_test_set_peppers)

# %%
pepper_reg = LinearRegression()

pepper_reg.fit(X_train_setpeppers, yPeppers_train_set)
pepper_reg.score(X_train_setpeppers, yPeppers_train_set)
# Out:
# 1.0

# %%
pepper_reg.score(X_test_set_peppers, yPeppers_test_set)
# Out:
# -0.002388894287008503

# %%
Pepper_DT = DecisionTreeRegressor(random_state=0).fit(X_train_setpeppers, yPeppers_train_set)
Pepper_DT.score(X_train_setpeppers, yPeppers_train_set)
# Out:
# 1.0

# %%
Pepper_DT.score(X_test_set_peppers, yPeppers_test_set)
# Out:
# 0.2894736842105262

# %%
peppers_mae_dt = mean_absolute_error(yPeppers_test_set.to_list(), Pepper_DT.predict(X_test_set_peppers))

peppers_mae_reg = mean_absolute_error(yPeppers_test_set.to_list(), pepper_reg.predict(X_test_set_peppers))

# %%
peppers_y_test_pred = Pepper_DT.predict(X_test_set_peppers)

# %% [markdown]
# ## Tomatoes

# %%
y_tomatoes = pd.read_csv("tomatoes.csv", thousands=',')

# %%
y_tomatoes
# Out:
#     Year  Value
# 0   2015    300
# 1   2014    245
# 2   2013    240
# 3   2012    200
# 4   2011    220
# 5   2010    200
# 6   2009    300
# 7   2008    260
# 8   2007    230
# 9   2006    230
# 10  2005    220
# 11  2004    260
# 12  2003    220
# 13  2002    210
# 14  2001    210
# 15  2000    170
# 16  1999    190
# 17  1998    210

# %%
df_tomatoes = df_all.loc[2006:2015]

# %%
df_tomatoes
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# ...

# %%
X_test_set_tomatoes = df_tomatoes.sample(n=3, random_state=42)
X_test_set_tomatoes
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX  TMIN   WDF2  WSF2
# DATE
# 2014  1.510  90.5  7919.0  7919.0  30.105  45.05  54.25  35.8  280.0  46.1
# 2007  1.400  96.0  6481.5  6481.5  29.550  47.90  59.60  37.4  200.0  48.1
# 2011  1.905  96.0  7396.0  7396.0  38.265  47.20  59.00  38.0  300.0  38.0

# %%
X_train_set_tomatoes = df_tomatoes.drop(index=X_test_set_tomatoes.index)

# %%
y_tomatoes = y_tomatoes[(y_tomatoes['Year'] >= df_tomatoes.index[0]) & (y_tomatoes['Year'] <= df_tomatoes.index[-1])].set_index('Year')
y_tomatoes = y_tomatoes[['Value']]
y_tomatoes_train_set = y_tomatoes.drop(index=X_test_set_tomatoes.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
y_tomatoes_test_set = y_tomatoes[y_tomatoes.index.isin(X_test_set_tomatoes.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
tomatoes_scaler = StandardScaler()

# %%
X_train_set_tomatoes = tomatoes_scaler.fit_transform(X_train_set_tomatoes)
X_test_set_tomatoes = tomatoes_scaler.transform(X_test_set_tomatoes)

# %%
tomatoes_reg = LinearRegression()

tomatoes_reg.fit(X_train_set_tomatoes, y_tomatoes_train_set)
tomatoes_reg.score(X_train_set_tomatoes, y_tomatoes_train_set)
# Out:
# 1.0

# %%
tomatoes_reg.score(X_test_set_tomatoes, y_tomatoes_test_set)
# Out:
# -21.650487499044743

# %%
Tomatoes_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set_tomatoes, y_tomatoes_train_set)
Tomatoes_DT.score(X_train_set_tomatoes, y_tomatoes_train_set)
# Out:
# 1.0

# %%
Tomatoes_DT.score(X_test_set_tomatoes, y_tomatoes_test_set)
# Out:
# -29.078947368421055

# %%
# to do create models for Cabbage, Carrots, Cucumbers, Squash

# %%
tomatoes_y_test_pred = Tomatoes_DT.predict(X_test_set_tomatoes)

# %%
tomatoes_mae_dt = mean_absolute_error(y_tomatoes_test_set.to_list(), Tomatoes_DT.predict(X_test_set_tomatoes))

tomatoes_mae_reg = mean_absolute_error(y_tomatoes_test_set.to_list(), tomatoes_reg.predict(X_test_set_tomatoes))

# %% [markdown]
# ## Cabbage

# %%
y_cabbage = pd.read_csv("cabbage.csv", thousands=',')

# %%
y_cabbage.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Value'], dtype='object')

# %%
y_cabbage.drop(['Unnamed: 0'], axis=1)
# Out:
#     Year  Value
# 0   2015    290
# 1   2014    270
# 2   2013    230
# 3   2012    250
# 4   2011    230
# 5   2010    280
# 6   2009    260
# 7   2008    280
# 8   2007    320
# 9   2006    340
# 10  2005    360
# 11  2004    270
# 12  2003    320
# 13  2002    300
# 14  2001    320
# 15  2000    250
# 16  1999    280
# 17  1998    260

# %%
df_cabbage = df_all.loc[2006:2015]

# %%
df_cabbage
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# ...

# %%
X_test_set_cabbage = df_cabbage.sample(n=3, random_state=42)
X_test_set_cabbage
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX  TMIN   WDF2  WSF2
# DATE
# 2014  1.510  90.5  7919.0  7919.0  30.105  45.05  54.25  35.8  280.0  46.1
# 2007  1.400  96.0  6481.5  6481.5  29.550  47.90  59.60  37.4  200.0  48.1
# 2011  1.905  96.0  7396.0  7396.0  38.265  47.20  59.00  38.0  300.0  38.0

# %%
X_train_set_cabbage = df_cabbage.drop(index=X_test_set_cabbage.index)

# %%
X_train_set_cabbage
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
# 2008   7.6  449.5  449.5  143.5  93.0   7.0  154.0  65.0  136.5   3.0  -5.5
# 2009   7.4  280.5  280.5  139.5  71.5  10.5  150.5  65.0  119.5   4.0 -14.0
# 2010   7.2  722.5  722.5  118.0  61.5   1.5  146.0  62.5  141.5  10.5  -1.0
# 2012   7.4  757.0  757.0  129.0  70.0   0.0  137.0  33.0  138.0  21.0   3.0
# 2013   7.4  518.0  518.0  152.0  81.5   6.0  159.5  64.0  134.0   8.5  -5.5
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# 2006  2.100  95.5  5853.0  5853.0  37.630  49.95  60.10  39.85  220.0  36.9
# 2008  2.650  92.0  6941.0  6941.0  41.345  45.90  56.60  36.35  230.0  42.9
# 2009  2.490  94.5  7391.0  7391.0  33.240  45.50  56.45  35.65  270.0  36.9
# ...

# %%
y_cabbage = y_cabbage[(y_cabbage['Year'] >= df_cabbage.index[0]) & (y_cabbage['Year'] <= df_cabbage.index[-1])].set_index('Year')
y_cabbage = y_cabbage[['Value']]
y_cabbage_train_set = y_cabbage.drop(index=X_test_set_cabbage.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
y_cabbage_test_set = y_cabbage[y_cabbage.index.isin(X_test_set_cabbage.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
y_cabbage_test_set
# Out:
# 2    320
# 1    230
# 0    270
# Name: Value, dtype: int64

# %%
cabbage_scaler = StandardScaler()

# %%
X_train_set_cabbage = cabbage_scaler.fit_transform(X_train_set_cabbage)
X_test_set_cabbage = cabbage_scaler.transform(X_test_set_cabbage)

# %%
cabbage_reg = LinearRegression()

cabbage_reg.fit(X_train_set_cabbage, y_cabbage_train_set)
cabbage_reg.score(X_train_set_cabbage, y_cabbage_train_set)
# Out:
# 1.0

# %%
cabbage_reg.score(X_test_set_cabbage, y_cabbage_test_set)
# Out:
# -2.9762807956411157

# %%
Cabbage_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set_cabbage, y_cabbage_train_set)
Cabbage_DT.score(X_train_set_cabbage, y_cabbage_train_set)
# Out:
# 1.0

# %%
Cabbage_DT.score(X_test_set_cabbage, y_cabbage_test_set)
# Out:
# -0.10655737704918034

# %%
cabbage_y_test_pred = Cabbage_DT.predict(X_test_set_cabbage)

# %%
cabbage_mae_dt = mean_absolute_error(y_cabbage_test_set.to_list(), Cabbage_DT.predict(X_test_set_cabbage))
cabbage_mae_reg = mean_absolute_error(y_cabbage_test_set.to_list(), cabbage_reg.predict(X_test_set_cabbage))

# %% [markdown]
# ## Carrots

# %%
y_carrots = pd.read_csv("carrots.csv", thousands=',')

# %%
y_carrots
# Out:
#     Year  Value
# 0   2015    240
# 1   2014    310
# 2   2013    290
# 3   2012    280
# 4   2011    260
# 5   2010    250
# 6   2009    270
# 7   2008    290
# 8   2007    300
# 9   2006    320
# 10  2005    360
# 11  2004    310
# 12  2003    350
# 13  2002    330
# 14  2001    350
# 15  2000    280
# 16  1999    280
# 17  1998    290

# %%
df_carrots = df_all.loc[2006:2015]

# %%
X_test_set_carrots = df_carrots.sample(n=3, random_state=42)
X_test_set_carrots
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX  TMIN   WDF2  WSF2
# DATE
# 2014  1.510  90.5  7919.0  7919.0  30.105  45.05  54.25  35.8  280.0  46.1
# 2007  1.400  96.0  6481.5  6481.5  29.550  47.90  59.60  37.4  200.0  48.1
# 2011  1.905  96.0  7396.0  7396.0  38.265  47.20  59.00  38.0  300.0  38.0

# %%
X_train_set_carrots = df_carrots.drop(index=X_test_set_carrots.index)

# %%
y_carrots = y_carrots[(y_carrots['Year'] >= df_carrots.index[0]) & (y_carrots['Year'] <= df_carrots.index[-1])].set_index('Year')
y_carrots = y_carrots[['Value']]
y_carrots_train_set = y_carrots.drop(index=X_test_set_carrots.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
y_carrots_test_set = y_carrots[y_carrots.index.isin(X_test_set_carrots.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
y_carrots_test_set
# Out:
# 2    300
# 1    260
# 0    310
# Name: Value, dtype: int64

# %%
carrots_scaler = StandardScaler()

# %%
X_train_set_carrots = carrots_scaler.fit_transform(X_train_set_carrots)
X_test_set_carrots = carrots_scaler.transform(X_test_set_carrots)

# %%
carrots_reg = LinearRegression()

carrots_reg.fit(X_train_set_carrots, y_carrots_train_set)
carrots_reg.score(X_train_set_carrots, y_carrots_train_set)
# Out:
# 1.0

# %%
carrots_reg.score(X_test_set_carrots, y_carrots_test_set)
# Out:
# -6.156128850490323

# %%
Carrots_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set_carrots, y_carrots_train_set)
Carrots_DT.score(X_train_set_carrots, y_carrots_train_set)
# Out:
# 1.0

# %%
Carrots_DT.score(X_test_set_carrots, y_carrots_test_set)
# Out:
# 0.2142857142857143

# %%
carrots_y_test_pred = Carrots_DT.predict(X_test_set_carrots)

# %%
carrots_mae_dt = mean_absolute_error(y_carrots_test_set.to_list(), Carrots_DT.predict(X_test_set_carrots))
carrots_mae_reg = mean_absolute_error(y_carrots_test_set.to_list(), carrots_reg.predict(X_test_set_carrots))

# %% [markdown]
# ## Cucumbers

# %%
y_cucumbers = pd.read_csv("cucumbers.csv", thousands=',')

# %%
y_cucumbers
# Out:
#     Year  Value
# 0   2015   5.90
# 1   2014   6.10
# 2   2013   5.80
# 3   2012   5.40
# 4   2011   5.60
# 5   2010   6.40
# 6   2009   5.80
# 7   2008   6.20
# 8   2007   5.30
# 9   2006   5.20
# 10  2005   4.80
# 11  2004   5.00
# 12  2003   5.40
# 13  2002   4.60
# 14  2001   4.25
# 15  2000   6.00
# 16  1999   6.00
# 17  1998   5.00

# %%
df_cucumbers = df_all.loc[2006:2015]

# %%
X_test_set_cucumbers = df_cucumbers.sample(n=3, random_state=42)
X_test_set_cucumbers
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2014   8.1  466.5  466.5  152.0  70.0  21.0  150.0  79.0  125.5   1.0 -13.5
# 2007   7.6  751.0  751.0  138.0  69.0   9.0  145.0  65.0  160.0  18.0 -14.0
# 2011   7.4  626.0  626.0  143.0  78.5   8.0  139.0  52.0  130.0  15.0 -12.0
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX  TMIN   WDF2  WSF2
# DATE
# 2014  1.510  90.5  7919.0  7919.0  30.105  45.05  54.25  35.8  280.0  46.1
# 2007  1.400  96.0  6481.5  6481.5  29.550  47.90  59.60  37.4  200.0  48.1
# 2011  1.905  96.0  7396.0  7396.0  38.265  47.20  59.00  38.0  300.0  38.0

# %%
X_train_set_cucumbers = df_cucumbers.drop(index=X_test_set_cucumbers.index)

# %%
y_cucumbers = y_cucumbers[(y_cucumbers['Year'] >= df_cucumbers.index[0]) & (y_cucumbers['Year'] <= df_cucumbers.index[-1])].set_index('Year')
y_cucumbers = y_cucumbers[['Value']]
y_cucumbers_train_set = y_cucumbers.drop(index=X_test_set_cucumbers.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
y_cucumbers_test_set = y_cucumbers[y_cucumbers.index.isin(X_test_set_cucumbers.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
cucumber_scaler = StandardScaler()

# %%
X_train_set_cucumbers = cucumber_scaler.fit_transform(X_train_set_cucumbers)
X_test_set_cucumbers = cucumber_scaler.transform(X_test_set_cucumbers)

# %%
cucumbers_reg = LinearRegression()

cucumbers_reg.fit(X_train_set_cucumbers, y_cucumbers_train_set)
cucumbers_reg.score(X_train_set_cucumbers, y_cucumbers_train_set)
# Out:
# 1.0

# %%
cucumbers_reg.score(X_test_set_cucumbers, y_cucumbers_test_set)
# Out:
# -6.437497660530074

# %%
Cucumbers_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set_cucumbers, y_cucumbers_train_set)
Cucumbers_DT.score(X_train_set_cucumbers, y_cucumbers_train_set)
# Out:
# 1.0

# %%
Cucumbers_DT.score(X_test_set_cucumbers, y_cucumbers_test_set)
# Out:
# -2.336734693877557

# %%
cucumbers_y_test_pred = Cucumbers_DT.predict(X_test_set_cucumbers)

# %%
cucumbers_mae_dt = mean_absolute_error(y_cucumbers_test_set.to_list(), Cucumbers_DT.predict(X_test_set_cucumbers))
cucumbers_mae_reg = mean_absolute_error(y_cucumbers_test_set.to_list(), cucumbers_reg.predict(X_test_set_cucumbers))

# %% [markdown]
# ## Squash

# %%
y_squash = pd.read_csv("squah.csv", thousands=',')

# %%
y_squash
# Out:
#     Year  Value
# 0   2020    220
# 1   2019    200
# 2   2018    220
# 3   2017    230
# 4   2016    240
# 5   2015    200
# 6   2014    200
# 7   2013    200
# 8   2012    240
# 9   2011    220
# 10  2010    200
# 11  2009    210
# 12  2008    200
# 13  2007    190
# 14  2006    210
# 15  2005    220
# 16  2004    160
# 17  2003    190
# 18  2002    230
# 19  2001    200
# 20  2000    115

# %%
df_squash = df_all.loc[2006:2020]

# %%
X_test_set_squash = df_squash.sample(n=3, random_state=42)
X_test_set_squash
# Out:
#       AWND   CDSD   CLDD   DP01  DP10  DT00   DT32  DX32   DX70  DX90  EMNT  \
# DATE
# 2015   7.8  487.5  487.5  136.5  70.0  26.0  142.5  57.5  137.5   2.5 -24.5
# 2017   7.8  539.0  539.0  144.5  75.0   4.5  131.5  45.5  145.0  11.0 -10.5
# 2006   7.6  604.0  604.0  140.0  81.0   1.0  134.5  22.0  138.5  13.0  -1.5
#
#        EMXP  EMXT    HDSD    HTDD    PRCP   TAVG   TMAX   TMIN   WDF2  WSF2
# DATE
# 2015  2.060  90.0  7722.5  7722.5  32.915  46.75  57.75  35.65  320.0  38.0
# 2017  3.125  93.5  6080.5  6080.5  38.840  48.45  59.30  39.00  290.0  40.9
# 2006  2.100  95.5  5853.0  5853.0  37.630  49.95  60.10  39.85  220.0  36.9

# %%
X_train_set_squash = df_squash.drop(index=X_test_set_squash.index)

# %%
y_squash = y_squash[(y_squash['Year'] >= df_squash.index[0]) & (y_squash['Year'] <= df_squash.index[-1])].set_index('Year')
y_squash = y_squash[['Value']]
y_squash_train_set = y_squash.drop(index=X_test_set_squash.index)['Value'].reset_index().sort_values(by=['Year'])['Value']
y_squash_test_set = y_squash[y_squash.index.isin(X_test_set_squash.index.tolist())]['Value'].reset_index().sort_values(by=['Year'])['Value']

# %%
squash_scaler = StandardScaler()

# %%
X_train_set_squash = squash_scaler.fit_transform(X_train_set_squash)
X_test_set_squash = squash_scaler.transform(X_test_set_squash)

# %%
squash_reg = LinearRegression()

squash_reg.fit(X_train_set_squash, y_squash_train_set)
squash_reg.score(X_train_set_squash, y_squash_train_set)
# Out:
# 1.0

# %%
squash_reg.score(X_test_set_squash, y_squash_test_set)
# Out:
# -5.463586152485335

# %%
Squash_DT = DecisionTreeRegressor(random_state=0).fit(X_train_set_squash, y_squash_train_set)
Squash_DT.score(X_train_set_squash, y_squash_train_set)
# Out:
# 1.0

# %%
Squash_DT.score(X_test_set_squash, y_squash_test_set)
# Out:
# -2.857142857142857

# %%
squash_y_test_pred = Squash_DT.predict(X_test_set_squash)

# %%
squash_mae_dt = mean_absolute_error(y_squash_test_set.to_list(), Squash_DT.predict(X_test_set_squash))
squash_mae_reg = mean_absolute_error(y_squash_test_set.to_list(), squash_reg.predict(X_test_set_squash))

# %%
squash_mae_dt
# Out:
# 20.0

# %% [markdown]
# ## Data visualization

# %%
# import googlemaps
# from datetime import datetime

# gmaps = googlemaps.Client(key='')

# # Geocoding an address
# geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

# # Look up an address with reverse geocoding
# reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

# # Request directions via public transit
# now = datetime.now()
# directions_result = gmaps.directions("Sydney Town Hall",
#                                      "Parramatta, NSW",
#                                      mode="transit",
#                                      departure_time=now)

# %%
#Kalamazoo, Huron, Monroe, Montcalm, Allegan

# %%
locations = df3['NAME'].unique()
locations
# Out:
# array([], dtype=object)

# %%
#df3['NAME'][0]

# %%
# result_list = []

# for i in df3['NAME'].unique():
#     try:
        
#         geocode_result = gmaps.geocode(i)
        
#         result_list.append(geocode_result)
        
#     except:
#         print("Error", i, "is not good address")

# %%
# len(result_list)

# %%
len(locations)
# Out:
# 0

# %%
import json

# json_string = json.dumps(result_list)
# with open('geo_json_data.json', 'w') as outfile:
#     outfile.write(json_string)
    
with open('geo_json_data.json', 'r') as infile:
    result_list = json.load(infile)

# %%
result_list[0][0]['geometry']['location']
# Out:
# {'lat': 46.49771150000001, 'lng': -84.3475876}

# %%
loc = {"address":locations, "lat":[i[0]['geometry']['location']['lat'] for i in result_list], "lng":[i[0]['geometry']['location']['lng'] for i in result_list]}

# %%
#location_df = pd.DataFrame(data=loc)

# %%
#location_df.head()

# %%
# import plotly.graph_objects as go

# import pandas as pd


# location_df['text'] = location_df['address'] + '' + str(location_df['lat']) + ', ' + str(location_df['lng']) + ''

# fig = go.Figure(data=go.Scattergeo(
#         lon = location_df['lng'],
#         lat = location_df['lat'],
#         text = location_df['text'],
#         mode = 'markers',
#         ))

# fig.update_layout(
#         title = 'Locations',
#         geo_scope='usa',
#     )
# fig.show()

# %%
#import plotly.express as px

# %%
temperatures_df = df_all[['TMAX', 'TMIN', 'TAVG']]
temperatures_df = temperatures_df.reset_index()
temperatures_df
# Out:
#     DATE   TMAX   TMIN   TAVG
# 0   2006  60.10  39.85  49.95
# 1   2007  59.60  37.40  47.90
# 2   2008  56.60  36.35  45.90
# 3   2009  56.45  35.65  45.50
# 4   2010  59.15  39.10  48.30
# 5   2011  59.00  38.00  47.20
# 6   2012  60.40  40.40  50.30
# 7   2013  55.90  36.25  45.95
# 8   2014  54.25  35.80  45.05
# 9   2015  57.75  35.65  46.75
# 10  2016  59.90  39.30  49.15
# 11  2017  59.30  39.00  48.45
# 12  2018  57.35  37.80  46.90
# 13  2019  56.65  36.70  46.20
# 14  2020  59.20  39.05  48.40

# %%
# fig = go.Figure()
# fig.add_trace(go.Scatter(x=temperatures_df['DATE'], y=temperatures_df['TMAX'],
#                     mode='lines+markers',
#                     name='TMAX'))
# fig.add_trace(go.Scatter(x=temperatures_df['DATE'], y=temperatures_df['TMIN'],
#                     mode='lines+markers',
#                     name='TMIN'))
# fig.add_trace(go.Scatter(x=temperatures_df['DATE'], y=temperatures_df['TAVG'],
#                     mode='lines+markers', name='TAVG'))
# fig.add_trace(go.Scatter(x=y.reset_index()['Year'], y=y.reset_index()['Value'],
#                     mode='lines+markers', name='Cabbage'))
# fig.show()

# %%
#y.reset_index()

# %%
# fig = go.Figure()
# fig.add_trace(go.Scatter(x=temperatures_df['DATE'], y=temperatures_df['TMAX'],
#                     mode='lines+markers',
#                     name='TMAX'))
# fig.add_trace(go.Scatter(x=temperatures_df['DATE'], y=temperatures_df['TMIN'],
#                     mode='lines+markers',
#                     name='TMIN'))
# fig.add_trace(go.Scatter(x=temperatures_df['DATE'], y=temperatures_df['TAVG'],
#                     mode='lines+markers', name='TAVG'))

# fig.show()

# %%
df_all.shape
# Out:
# (15, 21)

# %%
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go

# fig = make_subplots(rows=6, cols=6, subplot_titles=(df_all.columns))


# for index, i in enumerate(df_all.columns):
#     #print(index, index//5, index%5)
#     fig.add_trace(
#         go.Scatter(x=temperatures_df['DATE'], y=df_all[i], name=i),
#         row=index//6+1, col=index%6+1
#     )
#     fig.add_trace(go.Scatter(x=y.reset_index()['Year'], y=y.reset_index()['Value'],
#                     mode='lines+markers', name='Cabbage', line=dict(color="#03f8fc")), row=index//6+1, col=index%6+1)
    
# fig.update_layout(height=1600, width=1800, title_text="Side By Side Subplots")
# fig.show()

# %%
# to do create models for Cabbage, Carrots, Cucumbers, Squash

# %%
d_mean = {'Crop': ['Asparagus', 'Cabbage', 'Carrots', 'Cucumbers', 'Onions', 'Peppers', 'Pumpkins', 'Squash', 'Tomatoes'], 
     'DecisionTreeScore': [-0.8571428571428572, 0.016393442622950838, -0.3571428571428572, -2.336734693877557, 
                           -0.030612244897959107, -0.3421052631578949, -96.5, -2.857142857142857, -16.447368421052634]}

# %%
lr_mean = {'Crop': ['Asparagus', 'Cabbage', 'Carrots', 'Cucumbers', 'Onions', 'Peppers', 'Pumpkins', 'Squash', 'Tomatoes'], 
     'LinearRegressionScore': [-0.602697828623173, 0.1202842429422103, -2.9144439713147494, -8.054700351231048, 
                           -0.14897589695893965, 0.8801650755720081, -35.68599972837449, -9.440739538048685, -16.729810523321508]}

# %%
DT_df_mean = pd.DataFrame(data = d_mean)

selection = alt.selection_single()
DT_Scores_chart_mean = alt.Chart(DT_df_mean).mark_bar().encode(
    # encode x as the percent, and hide the axis
    x = alt.X('DecisionTreeScore:Q', title = ""),
    y=alt.Y('Crop'),
    tooltip = [alt.Tooltip('DecisionTreeScore:Q'),
               alt.Tooltip('Crop:N')
              ],
    color=alt.condition(selection, 'DecisionTreeScore:Q', alt.value('grey'))
).add_selection(selection)

# %%
DT_Scores_chart_mean
# Out:
# alt.Chart(...)

# %%
LR_df_mean = pd.DataFrame(data = lr_mean)


LR_Scores_chart_mean = alt.Chart(LR_df_mean).mark_bar().encode(
    # encode x as the percent, and hide the axis
    x = alt.X('LinearRegressionScore:Q', title = ""),
    y=alt.Y('Crop'),
    tooltip = [alt.Tooltip('LinearRegressionScore:Q'),
               alt.Tooltip('Crop:N')
              ],
    color=alt.condition(selection, 'LinearRegressionScore:Q', alt.value('grey'))
).add_selection(selection)

# %%
LR_Scores_chart_mean
# Out:
# alt.Chart(...)

# %%
d_median = {'Crop': ['Asparagus', 'Cabbage', 'Carrots', 'Cucumbers', 'Onions', 'Peppers', 'Pumpkins', 'Squash', 'Tomatoes'], 
     'DecisionTreeScore': [-0.8571428571428572, -0.10655737704918034, 0.2142857142857143, -2.336734693877557, 0.41836734693877553, 0.2894736842105262, 
                          -102.49999999999999, -2.857142857142857, -29.078947368421055 ]}

# %%
lr_median = {'Crop': ['Asparagus', 'Cabbage', 'Carrots', 'Cucumbers', 'Onions', 'Peppers', 'Pumpkins', 'Squash', 'Tomatoes'], 
     'LinearRegressionScore': [-1.9487223514578318, -2.9762807956411157, -6.156128850490323, -6.437497660530074, -0.24089196816479563,
                               -0.002388894287008503, -66.64782060458961, -5.463586152485335,  -21.650487499044743 ]}

# %%
DT_df_median = pd.DataFrame(data = d_median)

selection = alt.selection_single()
DT_Scores_chart_median = alt.Chart(DT_df_median).mark_bar().encode(
    # encode x as the percent, and hide the axis
    x = alt.X('DecisionTreeScore:Q', title = "median"),
    y=alt.Y('Crop'),
    tooltip = [alt.Tooltip('DecisionTreeScore:Q'),
               alt.Tooltip('Crop:N')
              ],
    color=alt.condition(selection, 'DecisionTreeScore:Q', alt.value('grey'))
).add_selection(selection)

# %%
DT_Scores_chart_median | DT_Scores_chart_mean
# Out:
# alt.HConcatChart(...)

# %%
LR_df_median = pd.DataFrame(data = lr_median)


LR_Scores_chart_median = alt.Chart(LR_df_median).mark_bar().encode(
    # encode x as the percent, and hide the axis
    x = alt.X('LinearRegressionScore:Q', title = "median"),
    y=alt.Y('Crop'),
    tooltip = [alt.Tooltip('LinearRegressionScore:Q'),
               alt.Tooltip('Crop:N')
              ],
    color=alt.condition(selection, 'LinearRegressionScore:Q', alt.value('grey'))
).add_selection(selection)

# %%
LR_Scores_chart_median | LR_Scores_chart_mean
# Out:
# alt.HConcatChart(...)

# %%
dt_MAE = {'Crop': ['Asparagus', 'Cabbage', 'Carrots', 'Cucumbers', 'Onions', 'Peppers', 'Pumpkins', 'Squash', 'Tomatoes'], 
     'Decision Tree MAE': [asparagus_mae_dt, cabbage_mae_dt, carrots_mae_dt, cucumbers_mae_dt, onion_mae_dt, peppers_mae_dt, 
                         pumpkin_mae_dt, squash_mae_dt, tomatoes_mae_dt]}

# %%
lr_MAE = {'Crop': ['Asparagus', 'Cabbage', 'Carrots', 'Cucumbers', 'Onions', 'Peppers', 'Pumpkins', 'Squash', 'Tomatoes'], 
     'Linear Regression MAE': [ asparagus_mae_reg, cabbage_mae_reg, carrots_mae_reg, cucumbers_mae_reg, onion_mae_reg, peppers_mae_reg, 
                              pumpkin_mae_reg, squash_mae_reg, tomatoes_mae_reg ]}

# %%
lr_MAE_df = pd.DataFrame(data = lr_MAE)


lr_mae_chart = alt.Chart(lr_MAE_df).mark_bar().encode(
    # encode x as the percent, and hide the axis
    x = alt.X('Linear Regression MAE:Q', title = "MAE"),
    y=alt.Y('Crop'),
    tooltip = [alt.Tooltip('Linear Regression MAE:Q'),
               alt.Tooltip('Crop:N')
              ],
    color=alt.condition(selection, 'Linear Regression MAE:Q', alt.value('grey'))
).add_selection(selection)

# %%
lr_mae_chart
# Out:
# alt.Chart(...)

# %%
dt_MAE_df = pd.DataFrame(data = dt_MAE)


dt_mae_chart = alt.Chart(dt_MAE_df).mark_bar().encode(
    # encode x as the percent, and hide the axis
    x = alt.X('Decision Tree MAE:Q', title = "MAE"),
    y=alt.Y('Crop'),
    tooltip = [alt.Tooltip('Decision Tree MAE:Q'),
               alt.Tooltip('Crop:N')
              ],
    color=alt.condition(selection, 'Decision Tree MAE:Q', alt.value('grey'))
).add_selection(selection)

# %%
dt_mae_chart
# Out:
# alt.Chart(...)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
DTprobs = Cucumbers_DT.predict_proba(X_test_set_cucumbers)
LRprobs = cucumbers_reg.predict_proba(X_test_set_cucumbers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-346-319dee2ec0a6> in <module>
# ----> 1 DTprobs = Cucumbers_DT.predict_proba(X_test_set_cucumbers)
#       2 LRprobs = cucumbers_reg.predict_proba(X_test_set_cucumbers)
#
# AttributeError: 'DecisionTreeRegressor' object has no attribute 'predict_proba'
